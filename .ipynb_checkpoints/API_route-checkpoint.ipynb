# %%
import requests
import psycopg2
import socket
import json
from datetime import datetime

# %%
# Substitui com os teus dados reais
HOST = "db.nhbyslgfifrxsubejasw.supabase.co"
DB = "postgres"
USER = "postgres"
PASSWORD = "Database_99_!_route"  # Substitui por completo
PORT = "5432"

try:
    print("🟡 A ligar ao Supabase...")
    connection = psycopg2.connect(
        host=HOST,
        database=DB,
        user=USER,
        password=PASSWORD,
        port=PORT
    )

    print("✅ Ligação estabelecida com sucesso!")

    cursor = connection.cursor()
    cursor.execute("SELECT NOW();")
    resultado = cursor.fetchone()
    print("🕒 Hora atual no servidor:", resultado)

    cursor.close()
    connection.close()
    print("🔒 Ligação fechada.")

except Exception as e:
    print("❌ Erro ao ligar à base de dados:", e)
# Out:
# 🟡 A ligar ao Supabase...
# ✅ Ligação estabelecida com sucesso!
# 🕒 Hora atual no servidor: (datetime.datetime(2025, 5, 17, 17, 10, 20, 308739, tzinfo=datetime.timezone.utc),)
# 🔒 Ligação fechada.

# %%
#Connect to the server

print("🟡 A ligar ao Supabase...")
connection = psycopg2.connect(
    host=HOST,
    database=DB,
    user=USER,
    password=PASSWORD,
    port=PORT
)

print("✅ Ligação estabelecida com sucesso!")

cursor = connection.cursor()
cursor.execute("SELECT NOW();")
resultado = cursor.fetchone()
print("🕒 Hora atual no servidor:", resultado)

# ✈️ API key and airport
API_KEY = 'abcf21-5fbf11'  # Replace with your actual API key
# Out:
# 🟡 A ligar ao Supabase...
# ✅ Ligação estabelecida com sucesso!
# 🕒 Hora atual no servidor: (datetime.datetime(2025, 5, 17, 17, 10, 20, 521291, tzinfo=datetime.timezone.utc),)

# %%
# ✈️ API key and airport
API_KEY = 'abcf21-5fbf11'  # Replace with your actual API key
AIRPORT = 'LIS'

# 🔁 Buscar a lista de IATA dos aeroportos da Europa
def get_european_airports():
    cursor.execute('SELECT "IATA" FROM public."Airports" WHERE "IATA" IS NOT NULL;')
    return [row[0] for row in cursor.fetchall()]

# 📱 Obter voos para um aeroporto
def get_flights(flight_type, airport_code):
    url = f'https://aviation-edge.com/v2/public/timetable?key={API_KEY}&iataCode={airport_code}&type={flight_type}'
    response = requests.get(url)

    if response.status_code == 200:
        print(f"✅ {flight_type.capitalize()} flights fetched successfully for {airport_code}.")
        return response.json()
    else:
        print(f"❌ Failed to fetch {flight_type} flights for {airport_code} ({response.status_code})")
        return []

def get_airport_city_country(iata_code):
    if not iata_code:
        return '', ''
    cursor.execute('SELECT "Airport_name", "Country" FROM public."Airports" WHERE "IATA" = %s;', (iata_code,))
    result = cursor.fetchone()
    return result if result else ('', '')

# 📂 Guardar os voos na base de dados

def save_flights(flights, flight_type):
    today = datetime.now().date()
    total = 0

    for flight in flights:
        if not isinstance(flight, dict):
            print(f"⚠️ Skipping non-dict flight record: {flight}")
            continue

        try:
            dep_info = flight.get('departure', {})
            arr_info = flight.get('arrival', {})

            dep_iata = dep_info.get('iataCode', '')
            arr_iata = arr_info.get('iataCode', '')

            dep_city, dep_country = get_airport_city_country(dep_iata)
            arr_city, arr_country = get_airport_city_country(arr_iata)

            cursor.execute('''
                INSERT INTO flights(
                    flight_number, airline_iata, airline_name,
                    dep_iata, dep_time, arr_iata, arr_time,
                    reg_number, status, direction, fetch_date,
                    dep_city, dep_country, arr_city, arr_country
                ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            ''', (
                flight.get('flight', {}).get('iataNumber', ''),
                flight.get('airline', {}).get('iataCode', ''),
                flight.get('airline', {}).get('name', ''),
                dep_iata,
                dep_info.get('scheduledTime', None),
                arr_iata,
                arr_info.get('scheduledTime', None),
                flight.get('regNumber', ''),
                flight.get('status', ''),
                flight_type,
                today,
                dep_city,
                dep_country,
                arr_city,
                arr_country
            ))
            total += 1
        except Exception as e:
            flight_num = flight.get('flight', {}).get('iataNumber', 'UNKNOWN') if isinstance(flight, dict) else 'UNKNOWN'
            print(f"⚠️ Error inserting flight {flight_num}: {e}")
            connection.rollback()

    connection.commit()
    print(f"✅ {total} {flight_type} flights saved to the database.")


# 🚀 Executar para todos os aeroportos
european_airports = get_european_airports()

for airport_code in european_airports:
    departures = get_flights('departure', airport_code)
    arrivals = get_flights('arrival', airport_code)

    save_flights(departures, 'departure')
    save_flights(arrivals, 'arrival')
# Out:
# ✅ Departure flights fetched successfully for BRU.
# ✅ Arrival flights fetched successfully for BRU.
# ✅ 244 departure flights saved to the database.
# ✅ 282 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CRL.
# ✅ Arrival flights fetched successfully for CRL.
# ✅ 63 departure flights saved to the database.
# ✅ 79 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LGG.
# ✅ Arrival flights fetched successfully for LGG.
# ✅ 31 departure flights saved to the database.
# ✅ 34 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for OST.
# ✅ Arrival flights fetched successfully for OST.
# ✅ 5 departure flights saved to the database.
# ✅ 6 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for AJA.
# ✅ Arrival flights fetched successfully for AJA.
# ✅ 31 departure flights saved to the database.
# ✅ 32 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BIA.
# ✅ Arrival flights fetched successfully for BIA.
# ✅ 44 departure flights saved to the database.
# ✅ 50 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BVA.
# ✅ Arrival flights fetched successfully for BVA.
# ✅ 40 departure flights saved to the database.
# ✅ 43 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for EGC.
# ✅ Arrival flights fetched successfully for EGC.
# ✅ 3 departure flights saved to the database.
# ✅ 3 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BZR.
# ✅ Arrival flights fetched successfully for BZR.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BIQ.
# ✅ Arrival flights fetched successfully for BIQ.
# ✅ 15 departure flights saved to the database.
# ✅ 19 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BOD.
# ✅ Arrival flights fetched successfully for BOD.
# ✅ 68 departure flights saved to the database.
# ✅ 84 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BES.
# ✅ Arrival flights fetched successfully for BES.
# ✅ 10 departure flights saved to the database.
# ✅ 26 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CCF.
# ✅ Arrival flights fetched successfully for CCF.
# ✅ 4 departure flights saved to the database.
# ✅ 5 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for XCR.
# ✅ Arrival flights fetched successfully for XCR.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CMF.
# ✅ Arrival flights fetched successfully for CMF.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for DNR.
# ✅ Arrival flights fetched successfully for DNR.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for FSC.
# ✅ Arrival flights fetched successfully for FSC.
# ✅ 20 departure flights saved to the database.
# ✅ 23 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GNB.
# ✅ Arrival flights fetched successfully for GNB.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LRH.
# ✅ Arrival flights fetched successfully for LRH.
# ✅ 5 departure flights saved to the database.
# ✅ 6 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LIL.
# ✅ Arrival flights fetched successfully for LIL.
# ✅ 16 departure flights saved to the database.
# ✅ 17 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LIG.
# ✅ Arrival flights fetched successfully for LIG.
# ✅ 4 departure flights saved to the database.
# ✅ 4 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LYS.
# ✅ Arrival flights fetched successfully for LYS.
# ✅ 130 departure flights saved to the database.
# ✅ 164 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MRS.
# ✅ Arrival flights fetched successfully for MRS.
# ✅ 138 departure flights saved to the database.
# ✅ 186 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BSL.
# ✅ Arrival flights fetched successfully for BSL.
# ✅ 66 departure flights saved to the database.
# ✅ 97 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for NTE.
# ✅ Arrival flights fetched successfully for NTE.
# ✅ 51 departure flights saved to the database.
# ✅ 80 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for NCE.
# ✅ Arrival flights fetched successfully for NCE.
# ✅ 247 departure flights saved to the database.
# ✅ 300 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for FNI.
# ✅ Arrival flights fetched successfully for FNI.
# ✅ 1 departure flights saved to the database.
# ✅ 2 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CDG.
# ✅ Arrival flights fetched successfully for CDG.
# ✅ 1277 departure flights saved to the database.
# ✅ 1083 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ORY.
# ✅ Arrival flights fetched successfully for ORY.
# ✅ 256 departure flights saved to the database.
# ✅ 294 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PUF.
# ✅ Arrival flights fetched successfully for PUF.
# ✅ 7 departure flights saved to the database.
# ✅ 14 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PGF.
# ✅ Arrival flights fetched successfully for PGF.
# ✅ 2 departure flights saved to the database.
# ✅ 3 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PIS.
# ✅ Arrival flights fetched successfully for PIS.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for RDZ.
# ✅ Arrival flights fetched successfully for RDZ.
# ✅ 2 departure flights saved to the database.
# ✅ 2 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for EBU.
# ✅ Arrival flights fetched successfully for EBU.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SXB.
# ✅ Arrival flights fetched successfully for SXB.
# ✅ 9 departure flights saved to the database.
# ✅ 9 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TLN.
# ✅ Arrival flights fetched successfully for TLN.
# ✅ 4 departure flights saved to the database.
# ✅ 8 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TLS.
# ✅ Arrival flights fetched successfully for TLS.
# ✅ 90 departure flights saved to the database.
# ✅ 125 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TUF.
# ✅ Arrival flights fetched successfully for TUF.
# ✅ 2 departure flights saved to the database.
# ✅ 2 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GIB.
# ✅ Arrival flights fetched successfully for GIB.
# ✅ 11 departure flights saved to the database.
# ✅ 5 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GCI.
# ✅ Arrival flights fetched successfully for GCI.
# ✅ 26 departure flights saved to the database.
# ✅ 39 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for JER.
# ✅ Arrival flights fetched successfully for JER.
# ✅ 35 departure flights saved to the database.
# ✅ 56 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ORK.
# ✅ Arrival flights fetched successfully for ORK.
# ✅ 35 departure flights saved to the database.
# ✅ 45 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for DUB.
# ✅ Arrival flights fetched successfully for DUB.
# ✅ 420 departure flights saved to the database.
# ✅ 442 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KIR.
# ✅ Arrival flights fetched successfully for KIR.
# ✅ 3 departure flights saved to the database.
# ✅ 3 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for NOC.
# ✅ Arrival flights fetched successfully for NOC.
# ✅ 6 departure flights saved to the database.
# ✅ 6 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SNN.
# ✅ Arrival flights fetched successfully for SNN.
# ✅ 30 departure flights saved to the database.
# ✅ 34 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for IOM.
# ✅ Arrival flights fetched successfully for IOM.
# ✅ 15 departure flights saved to the database.
# ✅ 24 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LUX.
# ✅ Arrival flights fetched successfully for LUX.
# ✅ 45 departure flights saved to the database.
# ✅ 69 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for AMS.
# ✅ Arrival flights fetched successfully for AMS.
# ✅ 1306 departure flights saved to the database.
# ✅ 1201 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for EIN.
# ✅ Arrival flights fetched successfully for EIN.
# ✅ 34 departure flights saved to the database.
# ✅ 41 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GRQ.
# ✅ Arrival flights fetched successfully for GRQ.
# ✅ 4 departure flights saved to the database.
# ✅ 3 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MST.
# ✅ Arrival flights fetched successfully for MST.
# ✅ 5 departure flights saved to the database.
# ✅ 6 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for RTM.
# ✅ Arrival flights fetched successfully for RTM.
# ✅ 20 departure flights saved to the database.
# ✅ 28 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BYJ.
# ✅ Arrival flights fetched successfully for BYJ.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for FAO.
# ✅ Arrival flights fetched successfully for FAO.
# ✅ 131 departure flights saved to the database.
# ✅ 140 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for FNC.
# ✅ Arrival flights fetched successfully for FNC.
# ✅ 87 departure flights saved to the database.
# ✅ 100 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PXO.
# ✅ Arrival flights fetched successfully for PXO.
# ✅ 3 departure flights saved to the database.
# ✅ 5 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LIS.
# ✅ Arrival flights fetched successfully for LIS.
# ✅ 641 departure flights saved to the database.
# ✅ 629 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for OPO.
# ✅ Arrival flights fetched successfully for OPO.
# ✅ 197 departure flights saved to the database.
# ✅ 245 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PDL.
# ✅ Arrival flights fetched successfully for PDL.
# ✅ 52 departure flights saved to the database.
# ✅ 69 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TER.
# ✅ Arrival flights fetched successfully for TER.
# ✅ 27 departure flights saved to the database.
# ✅ 26 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LCG.
# ✅ Arrival flights fetched successfully for LCG.
# ✅ 38 departure flights saved to the database.
# ✅ 38 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ALC.
# ✅ Arrival flights fetched successfully for ALC.
# ✅ 182 departure flights saved to the database.
# ✅ 193 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LEI.
# ✅ Arrival flights fetched successfully for LEI.
# ✅ 20 departure flights saved to the database.
# ✅ 21 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for OVD.
# ✅ Arrival flights fetched successfully for OVD.
# ✅ 29 departure flights saved to the database.
# ✅ 38 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BCN.
# ✅ Arrival flights fetched successfully for BCN.
# ✅ 682 departure flights saved to the database.
# ✅ 704 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for FUE.
# ✅ Arrival flights fetched successfully for FUE.
# ✅ 87 departure flights saved to the database.
# ✅ 89 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GRO.
# ✅ Arrival flights fetched successfully for GRO.
# ✅ 22 departure flights saved to the database.
# ✅ 24 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LPA.
# ✅ Arrival flights fetched successfully for LPA.
# ✅ 208 departure flights saved to the database.
# ✅ 251 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GRX.
# ✅ Arrival flights fetched successfully for GRX.
# ✅ 27 departure flights saved to the database.
# ✅ 30 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for HSK.
# ✅ Arrival flights fetched successfully for HSK.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for IBZ.
# ✅ Arrival flights fetched successfully for IBZ.
# ✅ 165 departure flights saved to the database.
# ✅ 169 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for XRY.
# ✅ Arrival flights fetched successfully for XRY.
# ✅ 21 departure flights saved to the database.
# ✅ 24 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SPC.
# ✅ Arrival flights fetched successfully for SPC.
# ✅ 36 departure flights saved to the database.
# ✅ 34 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ACE.
# ✅ Arrival flights fetched successfully for ACE.
# ✅ 100 departure flights saved to the database.
# ✅ 101 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ILD.
# ✅ Arrival flights fetched successfully for ILD.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MAD.
# ✅ Arrival flights fetched successfully for MAD.
# ✅ 1073 departure flights saved to the database.
# ✅ 1096 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for AGP.
# ✅ Arrival flights fetched successfully for AGP.
# ✅ 258 departure flights saved to the database.
# ✅ 293 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MAH.
# ❌ Failed to fetch arrival flights for MAH (404)
# ✅ 46 departure flights saved to the database.
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MJV.
# ✅ Arrival flights fetched successfully for MJV.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PMI.
# ✅ Arrival flights fetched successfully for PMI.
# ✅ 395 departure flights saved to the database.
# ✅ 436 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for REU.
# ✅ Arrival flights fetched successfully for REU.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SDR.
# ✅ Arrival flights fetched successfully for SDR.
# ✅ 17 departure flights saved to the database.
# ✅ 20 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SCQ.
# ✅ Arrival flights fetched successfully for SCQ.
# ✅ 37 departure flights saved to the database.
# ✅ 49 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SVQ.
# ✅ Arrival flights fetched successfully for SVQ.
# ✅ 93 departure flights saved to the database.
# ✅ 109 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TFN.
# ✅ Arrival flights fetched successfully for TFN.
# ✅ 133 departure flights saved to the database.
# ✅ 181 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TFS.
# ✅ Arrival flights fetched successfully for TFS.
# ✅ 134 departure flights saved to the database.
# ✅ 139 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for VLC.
# ✅ Arrival flights fetched successfully for VLC.
# ✅ 112 departure flights saved to the database.
# ✅ 146 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for VLL.
# ✅ Arrival flights fetched successfully for VLL.
# ✅ 3 departure flights saved to the database.
# ✅ 4 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ZAZ.
# ✅ Arrival flights fetched successfully for ZAZ.
# ✅ 18 departure flights saved to the database.
# ✅ 18 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GRZ.
# ✅ Arrival flights fetched successfully for GRZ.
# ✅ 16 departure flights saved to the database.
# ✅ 18 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KLU.
# ✅ Arrival flights fetched successfully for KLU.
# ✅ 5 departure flights saved to the database.
# ✅ 11 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for INN.
# ✅ Arrival flights fetched successfully for INN.
# ✅ 6 departure flights saved to the database.
# ✅ 11 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LNZ.
# ✅ Arrival flights fetched successfully for LNZ.
# ✅ 7 departure flights saved to the database.
# ✅ 9 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SZG.
# ✅ Arrival flights fetched successfully for SZG.
# ✅ 19 departure flights saved to the database.
# ✅ 21 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for VIE.
# ✅ Arrival flights fetched successfully for VIE.
# ✅ 371 departure flights saved to the database.
# ✅ 438 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for FKB.
# ✅ Arrival flights fetched successfully for FKB.
# ✅ 13 departure flights saved to the database.
# ✅ 21 arrival flights saved to the database.
# ❌ Failed to fetch departure flights for TXL (404)
# ✅ Arrival flights fetched successfully for TXL.
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SXF.
# ✅ Arrival flights fetched successfully for SXF.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BER.
# ✅ Arrival flights fetched successfully for BER.
# ✅ 237 departure flights saved to the database.
# ✅ 304 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BRE.
# ✅ Arrival flights fetched successfully for BRE.
# ✅ 31 departure flights saved to the database.
# ✅ 57 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CGN.
# ✅ Arrival flights fetched successfully for CGN.
# ✅ 80 departure flights saved to the database.
# ✅ 119 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for DTM.
# ✅ Arrival flights fetched successfully for DTM.
# ✅ 22 departure flights saved to the database.
# ✅ 28 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for DUS.
# ✅ Arrival flights fetched successfully for DUS.
# ✅ 184 departure flights saved to the database.
# ✅ 245 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for FRA.
# ✅ Arrival flights fetched successfully for FRA.
# ✅ 1132 departure flights saved to the database.
# ✅ 1074 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for HHN.
# ✅ Arrival flights fetched successfully for HHN.
# ✅ 21 departure flights saved to the database.
# ✅ 22 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MLH.
# ✅ Arrival flights fetched successfully for MLH.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BSL.
# ✅ Arrival flights fetched successfully for BSL.
# ✅ 66 departure flights saved to the database.
# ✅ 97 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for EAP.
# ✅ Arrival flights fetched successfully for EAP.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for FDH.
# ✅ Arrival flights fetched successfully for FDH.
# ✅ 4 departure flights saved to the database.
# ✅ 6 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for HAM.
# ✅ Arrival flights fetched successfully for HAM.
# ✅ 184 departure flights saved to the database.
# ✅ 236 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for HAJ.
# ✅ Arrival flights fetched successfully for HAJ.
# ✅ 64 departure flights saved to the database.
# ✅ 87 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LEJ.
# ✅ Arrival flights fetched successfully for LEJ.
# ✅ 46 departure flights saved to the database.
# ✅ 59 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LBC.
# ✅ Arrival flights fetched successfully for LBC.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for FMM.
# ✅ Arrival flights fetched successfully for FMM.
# ✅ 11 departure flights saved to the database.
# ✅ 15 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MUC.
# ✅ Arrival flights fetched successfully for MUC.
# ✅ 690 departure flights saved to the database.
# ✅ 706 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for NUE.
# ✅ Arrival flights fetched successfully for NUE.
# ✅ 50 departure flights saved to the database.
# ✅ 70 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for STR.
# ✅ Arrival flights fetched successfully for STR.
# ✅ 97 departure flights saved to the database.
# ✅ 152 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for NRN.
# ✅ Arrival flights fetched successfully for NRN.
# ✅ 15 departure flights saved to the database.
# ✅ 19 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ATH.
# ✅ Arrival flights fetched successfully for ATH.
# ✅ 427 departure flights saved to the database.
# ✅ 466 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CHQ.
# ✅ Arrival flights fetched successfully for CHQ.
# ✅ 54 departure flights saved to the database.
# ✅ 61 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for JKH.
# ✅ Arrival flights fetched successfully for JKH.
# ✅ 3 departure flights saved to the database.
# ✅ 3 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CFU.
# ✅ Arrival flights fetched successfully for CFU.
# ✅ 36 departure flights saved to the database.
# ✅ 38 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for HER.
# ✅ Arrival flights fetched successfully for HER.
# ✅ 117 departure flights saved to the database.
# ✅ 121 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KLX.
# ✅ Arrival flights fetched successfully for KLX.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for AOK.
# ✅ Arrival flights fetched successfully for AOK.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KVA.
# ✅ Arrival flights fetched successfully for KVA.
# ✅ 1 departure flights saved to the database.
# ✅ 1 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for EFL.
# ✅ Arrival flights fetched successfully for EFL.
# ✅ 10 departure flights saved to the database.
# ✅ 8 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KGS.
# ✅ Arrival flights fetched successfully for KGS.
# ✅ 41 departure flights saved to the database.
# ✅ 40 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for JMK.
# ✅ Arrival flights fetched successfully for JMK.
# ✅ 20 departure flights saved to the database.
# ✅ 16 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MJT.
# ✅ Arrival flights fetched successfully for MJT.
# ✅ 7 departure flights saved to the database.
# ✅ 7 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PVK.
# ✅ Arrival flights fetched successfully for PVK.
# ✅ 11 departure flights saved to the database.
# ✅ 12 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for RHO.
# ✅ Arrival flights fetched successfully for RHO.
# ✅ 105 departure flights saved to the database.
# ✅ 104 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SMI.
# ✅ Arrival flights fetched successfully for SMI.
# ✅ 6 departure flights saved to the database.
# ✅ 6 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for JTR.
# ✅ Arrival flights fetched successfully for JTR.
# ✅ 36 departure flights saved to the database.
# ✅ 37 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for JSI.
# ✅ Arrival flights fetched successfully for JSI.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SKU.
# ✅ Arrival flights fetched successfully for SKU.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SKG.
# ✅ Arrival flights fetched successfully for SKG.
# ✅ 67 departure flights saved to the database.
# ✅ 85 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for VOL.
# ✅ Arrival flights fetched successfully for VOL.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ZTH.
# ✅ Arrival flights fetched successfully for ZTH.
# ✅ 24 departure flights saved to the database.
# ✅ 21 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for AHO.
# ✅ Arrival flights fetched successfully for AHO.
# ✅ 15 departure flights saved to the database.
# ✅ 31 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for AOI.
# ✅ Arrival flights fetched successfully for AOI.
# ✅ 11 departure flights saved to the database.
# ✅ 10 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BRI.
# ✅ Arrival flights fetched successfully for BRI.
# ✅ 82 departure flights saved to the database.
# ✅ 129 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BGY.
# ✅ Arrival flights fetched successfully for BGY.
# ✅ 92 departure flights saved to the database.
# ✅ 111 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BLQ.
# ✅ Arrival flights fetched successfully for BLQ.
# ✅ 134 departure flights saved to the database.
# ✅ 195 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for VBS.
# ✅ Arrival flights fetched successfully for VBS.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BDS.
# ✅ Arrival flights fetched successfully for BDS.
# ✅ 51 departure flights saved to the database.
# ✅ 85 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CAG.
# ✅ Arrival flights fetched successfully for CAG.
# ✅ 47 departure flights saved to the database.
# ✅ 53 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CTA.
# ✅ Arrival flights fetched successfully for CTA.
# ✅ 135 departure flights saved to the database.
# ✅ 184 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CUF.
# ✅ Arrival flights fetched successfully for CUF.
# ✅ 2 departure flights saved to the database.
# ✅ 2 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for FLR.
# ✅ Arrival flights fetched successfully for FLR.
# ✅ 118 departure flights saved to the database.
# ✅ 162 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GOA.
# ✅ Arrival flights fetched successfully for GOA.
# ✅ 39 departure flights saved to the database.
# ✅ 79 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SUF.
# ✅ Arrival flights fetched successfully for SUF.
# ✅ 41 departure flights saved to the database.
# ✅ 79 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LIN.
# ✅ Arrival flights fetched successfully for LIN.
# ✅ 157 departure flights saved to the database.
# ✅ 184 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MXP.
# ✅ Arrival flights fetched successfully for MXP.
# ✅ 279 departure flights saved to the database.
# ✅ 318 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for NAP.
# ✅ Arrival flights fetched successfully for NAP.
# ✅ 156 departure flights saved to the database.
# ✅ 207 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for OLB.
# ✅ Arrival flights fetched successfully for OLB.
# ✅ 49 departure flights saved to the database.
# ✅ 47 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PMO.
# ✅ Arrival flights fetched successfully for PMO.
# ✅ 122 departure flights saved to the database.
# ✅ 151 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PEG.
# ✅ Arrival flights fetched successfully for PEG.
# ✅ 11 departure flights saved to the database.
# ✅ 11 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PSR.
# ✅ Arrival flights fetched successfully for PSR.
# ✅ 5 departure flights saved to the database.
# ✅ 5 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PSA.
# ✅ Arrival flights fetched successfully for PSA.
# ✅ 50 departure flights saved to the database.
# ✅ 61 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for RMI.
# ✅ Arrival flights fetched successfully for RMI.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for FCO.
# ✅ Arrival flights fetched successfully for FCO.
# ✅ 930 departure flights saved to the database.
# ✅ 1001 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CIA.
# ✅ Arrival flights fetched successfully for CIA.
# ✅ 27 departure flights saved to the database.
# ✅ 37 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TPS.
# ✅ Arrival flights fetched successfully for TPS.
# ✅ 8 departure flights saved to the database.
# ✅ 8 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TRS.
# ✅ Arrival flights fetched successfully for TRS.
# ✅ 35 departure flights saved to the database.
# ✅ 71 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TRN.
# ✅ Arrival flights fetched successfully for TRN.
# ✅ 79 departure flights saved to the database.
# ✅ 123 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for VCE.
# ✅ Arrival flights fetched successfully for VCE.
# ✅ 189 departure flights saved to the database.
# ✅ 230 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for VRN.
# ✅ Arrival flights fetched successfully for VRN.
# ✅ 37 departure flights saved to the database.
# ✅ 49 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BSL.
# ✅ Arrival flights fetched successfully for BSL.
# ✅ 66 departure flights saved to the database.
# ✅ 97 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BRN.
# ✅ Arrival flights fetched successfully for BRN.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GVA.
# ✅ Arrival flights fetched successfully for GVA.
# ✅ 231 departure flights saved to the database.
# ✅ 271 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ACH.
# ✅ Arrival flights fetched successfully for ACH.
# ✅ 5 departure flights saved to the database.
# ✅ 4 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ZRH.
# ✅ Arrival flights fetched successfully for ZRH.
# ✅ 493 departure flights saved to the database.
# ✅ 487 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BZG.
# ✅ Arrival flights fetched successfully for BZG.
# ✅ 2 departure flights saved to the database.
# ✅ 2 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GDN.
# ✅ Arrival flights fetched successfully for GDN.
# ✅ 51 departure flights saved to the database.
# ✅ 77 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KTW.
# ✅ Arrival flights fetched successfully for KTW.
# ✅ 41 departure flights saved to the database.
# ✅ 74 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KRK.
# ✅ Arrival flights fetched successfully for KRK.
# ✅ 94 departure flights saved to the database.
# ✅ 130 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LUZ.
# ✅ Arrival flights fetched successfully for LUZ.
# ✅ 5 departure flights saved to the database.
# ✅ 7 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LCJ.
# ✅ Arrival flights fetched successfully for LCJ.
# ✅ 3 departure flights saved to the database.
# ✅ 4 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for POZ.
# ✅ Arrival flights fetched successfully for POZ.
# ✅ 35 departure flights saved to the database.
# ✅ 51 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for RZE.
# ✅ Arrival flights fetched successfully for RZE.
# ✅ 13 departure flights saved to the database.
# ✅ 18 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SZZ.
# ✅ Arrival flights fetched successfully for SZZ.
# ✅ 5 departure flights saved to the database.
# ✅ 5 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for WAW.
# ✅ Arrival flights fetched successfully for WAW.
# ✅ 286 departure flights saved to the database.
# ✅ 321 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for WMI.
# ✅ Arrival flights fetched successfully for WMI.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for WRO.
# ✅ Arrival flights fetched successfully for WRO.
# ✅ 44 departure flights saved to the database.
# ✅ 64 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for OTP.
# ✅ Arrival flights fetched successfully for OTP.
# ✅ 157 departure flights saved to the database.
# ✅ 185 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CLJ.
# ✅ Arrival flights fetched successfully for CLJ.
# ✅ 23 departure flights saved to the database.
# ✅ 44 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CND.
# ✅ Arrival flights fetched successfully for CND.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for IAS.
# ✅ Arrival flights fetched successfully for IAS.
# ✅ 20 departure flights saved to the database.
# ✅ 33 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for OMR.
# ✅ Arrival flights fetched successfully for OMR.
# ✅ 2 departure flights saved to the database.
# ✅ 6 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SBZ.
# ✅ Arrival flights fetched successfully for SBZ.
# ✅ 3 departure flights saved to the database.
# ✅ 7 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TSR.
# ✅ Arrival flights fetched successfully for TSR.
# ✅ 15 departure flights saved to the database.
# ✅ 20 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TIA.
# ✅ Arrival flights fetched successfully for TIA.
# ✅ 67 departure flights saved to the database.
# ✅ 89 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for EVN.
# ✅ Arrival flights fetched successfully for EVN.
# ✅ 42 departure flights saved to the database.
# ✅ 58 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LWN.
# ✅ Arrival flights fetched successfully for LWN.
# ✅ 2 departure flights saved to the database.
# ✅ 1 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GYD.
# ✅ Arrival flights fetched successfully for GYD.
# ✅ 94 departure flights saved to the database.
# ✅ 113 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KVD.
# ✅ Arrival flights fetched successfully for KVD.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for NAJ.
# ✅ Arrival flights fetched successfully for NAJ.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GBB.
# ✅ Arrival flights fetched successfully for GBB.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LLK.
# ✅ Arrival flights fetched successfully for LLK.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GNA.
# ✅ Arrival flights fetched successfully for GNA.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GME.
# ✅ Arrival flights fetched successfully for GME.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MSQ.
# ✅ Arrival flights fetched successfully for MSQ.
# ✅ 33 departure flights saved to the database.
# ✅ 31 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BNX.
# ✅ Arrival flights fetched successfully for BNX.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SJJ.
# ✅ Arrival flights fetched successfully for SJJ.
# ✅ 25 departure flights saved to the database.
# ✅ 31 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TZL.
# ✅ Arrival flights fetched successfully for TZL.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for OMO.
# ✅ Arrival flights fetched successfully for OMO.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BOJ.
# ✅ Arrival flights fetched successfully for BOJ.
# ✅ 5 departure flights saved to the database.
# ✅ 6 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PDV.
# ✅ Arrival flights fetched successfully for PDV.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SOF.
# ✅ Arrival flights fetched successfully for SOF.
# ✅ 72 departure flights saved to the database.
# ✅ 94 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for VAR.
# ✅ Arrival flights fetched successfully for VAR.
# ✅ 17 departure flights saved to the database.
# ✅ 25 arrival flights saved to the database.
# ❌ Failed to fetch departure flights for DBV (404)
# ✅ Arrival flights fetched successfully for DBV.
# ✅ 0 departure flights saved to the database.
# ✅ 72 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ZAG.
# ✅ Arrival flights fetched successfully for ZAG.
# ✅ 87 departure flights saved to the database.
# ✅ 126 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for OSI.
# ✅ Arrival flights fetched successfully for OSI.
# ✅ 1 departure flights saved to the database.
# ✅ 2 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PUY.
# ✅ Arrival flights fetched successfully for PUY.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for RJK.
# ✅ Arrival flights fetched successfully for RJK.
# ✅ 5 departure flights saved to the database.
# ✅ 4 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SPU.
# ✅ Arrival flights fetched successfully for SPU.
# ✅ 84 departure flights saved to the database.
# ✅ 97 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ZAD.
# ✅ Arrival flights fetched successfully for ZAD.
# ✅ 20 departure flights saved to the database.
# ✅ 21 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LCA.
# ✅ Arrival flights fetched successfully for LCA.
# ✅ 107 departure flights saved to the database.
# ✅ 107 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PFO.
# ✅ Arrival flights fetched successfully for PFO.
# ✅ 36 departure flights saved to the database.
# ✅ 35 arrival flights saved to the database.
# ...
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ODS.
# ✅ Arrival flights fetched successfully for ODS.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SIP.
# ✅ Arrival flights fetched successfully for SIP.
# ✅ 2 departure flights saved to the database.
# ✅ 1 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for OZH.
# ✅ Arrival flights fetched successfully for OZH.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for AAL.
# ✅ Arrival flights fetched successfully for AAL.
# ✅ 23 departure flights saved to the database.
# ✅ 29 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for AAR.
# ✅ Arrival flights fetched successfully for AAR.
# ✅ 10 departure flights saved to the database.
# ✅ 15 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BLL.
# ✅ Arrival flights fetched successfully for BLL.
# ✅ 32 departure flights saved to the database.
# ✅ 63 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CPH.
# ✅ Arrival flights fetched successfully for CPH.
# ✅ 403 departure flights saved to the database.
# ✅ 447 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for FAE.
# ✅ Arrival flights fetched successfully for FAE.
# ✅ 4 departure flights saved to the database.
# ✅ 9 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MHQ.
# ✅ Arrival flights fetched successfully for MHQ.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for HEL.
# ✅ Arrival flights fetched successfully for HEL.
# ✅ 355 departure flights saved to the database.
# ✅ 478 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KTT.
# ✅ Arrival flights fetched successfully for KTT.
# ✅ 2 departure flights saved to the database.
# ✅ 5 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KUO.
# ✅ Arrival flights fetched successfully for KUO.
# ✅ 11 departure flights saved to the database.
# ✅ 11 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KAO.
# ✅ Arrival flights fetched successfully for KAO.
# ✅ 5 departure flights saved to the database.
# ✅ 2 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LPP.
# ✅ Arrival flights fetched successfully for LPP.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for OUL.
# ✅ Arrival flights fetched successfully for OUL.
# ✅ 23 departure flights saved to the database.
# ✅ 25 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for RVN.
# ✅ Arrival flights fetched successfully for RVN.
# ✅ 14 departure flights saved to the database.
# ✅ 22 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TMP.
# ✅ Arrival flights fetched successfully for TMP.
# ✅ 3 departure flights saved to the database.
# ✅ 5 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TKU.
# ✅ Arrival flights fetched successfully for TKU.
# ✅ 5 departure flights saved to the database.
# ✅ 5 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for VAA.
# ✅ Arrival flights fetched successfully for VAA.
# ✅ 2 departure flights saved to the database.
# ✅ 5 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for AEY.
# ✅ Arrival flights fetched successfully for AEY.
# ✅ 3 departure flights saved to the database.
# ✅ 4 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KEF.
# ✅ Arrival flights fetched successfully for KEF.
# ✅ 103 departure flights saved to the database.
# ✅ 120 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for RKV.
# ✅ Arrival flights fetched successfully for RKV.
# ✅ 8 departure flights saved to the database.
# ✅ 12 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for AES.
# ✅ Arrival flights fetched successfully for AES.
# ✅ 9 departure flights saved to the database.
# ✅ 16 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BGO.
# ✅ Arrival flights fetched successfully for BGO.
# ✅ 69 departure flights saved to the database.
# ✅ 89 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BOO.
# ✅ Arrival flights fetched successfully for BOO.
# ✅ 19 departure flights saved to the database.
# ✅ 22 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for HAU.
# ✅ Arrival flights fetched successfully for HAU.
# ✅ 5 departure flights saved to the database.
# ✅ 4 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KRS.
# ✅ Arrival flights fetched successfully for KRS.
# ✅ 8 departure flights saved to the database.
# ✅ 11 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for KSU.
# ✅ Arrival flights fetched successfully for KSU.
# ✅ 4 departure flights saved to the database.
# ✅ 5 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for OSL.
# ✅ Arrival flights fetched successfully for OSL.
# ✅ 204 departure flights saved to the database.
# ✅ 263 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for RYG.
# ✅ Arrival flights fetched successfully for RYG.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TRF.
# ✅ Arrival flights fetched successfully for TRF.
# ✅ 17 departure flights saved to the database.
# ✅ 15 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SVG.
# ✅ Arrival flights fetched successfully for SVG.
# ✅ 28 departure flights saved to the database.
# ✅ 40 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TOS.
# ✅ Arrival flights fetched successfully for TOS.
# ✅ 21 departure flights saved to the database.
# ✅ 31 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for TRD.
# ✅ Arrival flights fetched successfully for TRD.
# ✅ 31 departure flights saved to the database.
# ✅ 45 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GSE.
# ✅ Arrival flights fetched successfully for GSE.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GOT.
# ✅ Arrival flights fetched successfully for GOT.
# ✅ 67 departure flights saved to the database.
# ✅ 96 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LLA.
# ✅ Arrival flights fetched successfully for LLA.
# ✅ 8 departure flights saved to the database.
# ✅ 10 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MMX.
# ✅ Arrival flights fetched successfully for MMX.
# ✅ 8 departure flights saved to the database.
# ✅ 12 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for NRK.
# ✅ Arrival flights fetched successfully for NRK.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for OSD.
# ✅ Arrival flights fetched successfully for OSD.
# ✅ 5 departure flights saved to the database.
# ✅ 4 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ARN.
# ✅ Arrival flights fetched successfully for ARN.
# ✅ 222 departure flights saved to the database.
# ✅ 311 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BMA.
# ✅ Arrival flights fetched successfully for BMA.
# ✅ 3 departure flights saved to the database.
# ✅ 4 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for NYO.
# ✅ Arrival flights fetched successfully for NYO.
# ✅ 4 departure flights saved to the database.
# ✅ 2 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for VST.
# ✅ Arrival flights fetched successfully for VST.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for UME.
# ✅ Arrival flights fetched successfully for UME.
# ✅ 6 departure flights saved to the database.
# ✅ 13 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for VXO.
# ✅ Arrival flights fetched successfully for VXO.
# ✅ 1 departure flights saved to the database.
# ✅ 1 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for VBY.
# ✅ Arrival flights fetched successfully for VBY.
# ✅ 4 departure flights saved to the database.
# ✅ 8 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BHX.
# ✅ Arrival flights fetched successfully for BHX.
# ✅ 107 departure flights saved to the database.
# ✅ 141 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BOH.
# ✅ Arrival flights fetched successfully for BOH.
# ✅ 15 departure flights saved to the database.
# ✅ 22 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BRS.
# ✅ Arrival flights fetched successfully for BRS.
# ✅ 73 departure flights saved to the database.
# ✅ 104 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for CWL.
# ❌ Failed to fetch arrival flights for CWL (404)
# ✅ 15 departure flights saved to the database.
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for DSA.
# ✅ Arrival flights fetched successfully for DSA.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MME.
# ✅ Arrival flights fetched successfully for MME.
# ✅ 3 departure flights saved to the database.
# ✅ 10 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for EMA.
# ✅ Arrival flights fetched successfully for EMA.
# ✅ 30 departure flights saved to the database.
# ✅ 58 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for EXT.
# ✅ Arrival flights fetched successfully for EXT.
# ✅ 16 departure flights saved to the database.
# ✅ 16 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LBA.
# ✅ Arrival flights fetched successfully for LBA.
# ✅ 33 departure flights saved to the database.
# ✅ 51 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LPL.
# ✅ Arrival flights fetched successfully for LPL.
# ✅ 49 departure flights saved to the database.
# ✅ 54 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LCY.
# ✅ Arrival flights fetched successfully for LCY.
# ✅ 10 departure flights saved to the database.
# ✅ 6 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LGW.
# ✅ Arrival flights fetched successfully for LGW.
# ✅ 314 departure flights saved to the database.
# ✅ 356 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LHR.
# ✅ Arrival flights fetched successfully for LHR.
# ✅ 1263 departure flights saved to the database.
# ✅ 1107 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LTN.
# ✅ Arrival flights fetched successfully for LTN.
# ✅ 107 departure flights saved to the database.
# ✅ 143 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SEN.
# ✅ Arrival flights fetched successfully for SEN.
# ✅ 3 departure flights saved to the database.
# ✅ 6 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for STN.
# ✅ Arrival flights fetched successfully for STN.
# ✅ 209 departure flights saved to the database.
# ✅ 247 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for MAN.
# ✅ Arrival flights fetched successfully for MAN.
# ✅ 259 departure flights saved to the database.
# ✅ 297 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for NCL.
# ✅ Arrival flights fetched successfully for NCL.
# ✅ 58 departure flights saved to the database.
# ✅ 100 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for NQY.
# ✅ Arrival flights fetched successfully for NQY.
# ✅ 12 departure flights saved to the database.
# ✅ 14 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for NWI.
# ✅ Arrival flights fetched successfully for NWI.
# ✅ 6 departure flights saved to the database.
# ✅ 10 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for SOU.
# ✅ Arrival flights fetched successfully for SOU.
# ✅ 45 departure flights saved to the database.
# ✅ 36 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for ABZ.
# ✅ Arrival flights fetched successfully for ABZ.
# ✅ 32 departure flights saved to the database.
# ✅ 66 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for EDI.
# ✅ Arrival flights fetched successfully for EDI.
# ✅ 150 departure flights saved to the database.
# ✅ 206 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for GLA.
# ✅ Arrival flights fetched successfully for GLA.
# ✅ 89 departure flights saved to the database.
# ✅ 150 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for PIK.
# ✅ Arrival flights fetched successfully for PIK.
# ✅ 8 departure flights saved to the database.
# ✅ 13 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for INV.
# ✅ Arrival flights fetched successfully for INV.
# ✅ 18 departure flights saved to the database.
# ✅ 23 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BFS.
# ✅ Arrival flights fetched successfully for BFS.
# ✅ 28 departure flights saved to the database.
# ✅ 46 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for BHD.
# ✅ Arrival flights fetched successfully for BHD.
# ✅ 49 departure flights saved to the database.
# ✅ 74 arrival flights saved to the database.
# ✅ Departure flights fetched successfully for LDY.
# ✅ Arrival flights fetched successfully for LDY.
# ✅ 3 departure flights saved to the database.
# ✅ 5 arrival flights saved to the database.
