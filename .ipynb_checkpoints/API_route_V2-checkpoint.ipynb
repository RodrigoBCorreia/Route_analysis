# %%
import requests
import psycopg2
import socket
import json
from datetime import datetime
import time
import requests
from requests.exceptions import RequestException
import asyncio
import asyncpg
from psycopg2 import pool
import nest_asyncio

# %%
# Substitui com os teus dados reais
HOST = "aws-0-eu-west-3.pooler.supabase.com"
DB = "postgres"
USER = "postgres.nhbyslgfifrxsubejasw"
PASSWORD = "Database_99_!_route"  # Substitui por completo
PORT = "6543"

# %%
#Connect to the server

print("🟡 A ligar ao Supabase...")
connection = psycopg2.connect(
    host=HOST,
    database=DB,
    user=USER,
    password=PASSWORD,
    port=PORT
)

print("✅ Ligação estabelecida com sucesso!")

cursor = connection.cursor()
cursor.execute("SELECT NOW();")
resultado = cursor.fetchone()
print("🕒 Hora atual no servidor:", resultado)

# ✈️ API key and airport
API_KEY = 'abcf21-5fbf11'  # Replace with your actual API key
# Out:
# 🟡 A ligar ao Supabase...
# ✅ Ligação estabelecida com sucesso!
# 🕒 Hora atual no servidor: (datetime.datetime(2025, 6, 9, 10, 28, 15, 63367, tzinfo=datetime.timezone.utc),)

# %%
# — Helper to format a timedelta into d h m s —
def format_duration(td):
    total_seconds = int(td.total_seconds())
    days, rem = divmod(total_seconds, 86400)
    hours, rem = divmod(rem, 3600)
    minutes, seconds = divmod(rem, 60)
    parts = []
    if days:
        parts.append(f"{days}d")
    if hours or days:
        parts.append(f"{hours}h")
    if minutes or hours or days:
        parts.append(f"{minutes}m")
    parts.append(f"{seconds}s")
    return " ".join(parts)

# 🔁 Buscar a lista de IATA dos aeroportos da Europa
def get_european_airports():
    cursor.execute('SELECT "IATA" FROM public."Airports" WHERE "IATA" IS NOT NULL;')
    return [row[0] for row in cursor.fetchall()]

# 📱 Obter voos para um aeroporto
def get_flights(flight_type, airport_code, max_retries=3):
    url = f'https://aviation-edge.com/v2/public/timetable?key={API_KEY}&iataCode={airport_code}&type={flight_type}'
    for attempt in range(1, max_retries+1):
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            print(f"✅ {flight_type.capitalize()} flights fetched successfully for {airport_code}.")
            return response.json()
        except RequestException as e:
            # This will catch DNS errors, timeouts, HTTP errors, etc.
            wait = 2 ** (attempt - 1)
            print(f"⚠️ [{airport_code}] Attempt {attempt}/{max_retries} failed: {e!r}")
            if attempt < max_retries:
                print(f"   ↳ retrying in {wait}s…")
                time.sleep(wait)
            else:
                print(f"❌ All {max_retries} attempts failed for {airport_code}. Skipping.")
    return []


# 📂 Guardar os voos na base de dados
def save_flights(flights, flight_type):
    today = datetime.now().date()
    total = 0
    for flight in flights:
        if not isinstance(flight, dict):
            print(f"⚠️ Skipping non-dict flight record: {flight}")
            continue
        try:
            dep = flight.get('departure', {})
            arr = flight.get('arrival', {})
            num = flight.get('flight', {}).get('iataNumber', '')
            dep_time = dep.get('scheduledTime')
            arr_time = arr.get('scheduledTime')
            # skip duplicates
            cursor.execute('''
                SELECT 1 FROM flights
                WHERE flight_number=%s AND dep_time=%s AND arr_time=%s
            ''', (num, dep_time, arr_time))
            if cursor.fetchone():
                continue
            # insert
            cursor.execute('''
                INSERT INTO flights(
                    flight_number, airline_iata, airline_name,
                    dep_iata, dep_time, arr_iata, arr_time,
                    reg_number, status, direction, fetch_date
                ) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
            ''', (
                num,
                flight.get('airline', {}).get('iataCode',''),
                flight.get('airline', {}).get('name',''),
                dep.get('iataCode',''),
                dep_time,
                arr.get('iataCode',''),
                arr_time,
                flight.get('regNumber',''),
                flight.get('status',''),
                flight_type,
                today
            ))
            total += 1
        except Exception as e:
            print(f"⚠️ Error inserting flight {num}: {e}")
            connection.rollback()
    connection.commit()
    print(f"✅ {total} new {flight_type} flights saved to the database.")

# 🕒 Timer start
process_start = datetime.now()
last_checkpoint = process_start
print(f"🚀 Process started at: {process_start.strftime('%Y-%m-%d %H:%M:%S')}")

# 🚀 Executar para todos os aeroportos
airports = get_european_airports()
total = len(airports)

for idx, code in enumerate(airports, start=1):
    print(f"\n🌍 Processing airport {idx}/{total}: {code}")

    deps = get_flights('departure', code)
    arrs = get_flights('arrival', code)
    save_flights(deps, 'departure')
    save_flights(arrs, 'arrival')

    now = datetime.now()
    lap = now - last_checkpoint
    total_elapsed = now - process_start
    last_checkpoint = now

    print(f"✅ Completed {idx}/{total}")
    print(f"⏱️ {format_duration(lap)} since last • {format_duration(total_elapsed)} total")
    print("-" * 40)

# 🕒 Timer end
end = datetime.now()
overall = end - process_start

print(f"\n🎉 All {total} airports processed.")
print(f"🕔 Completed at: {end.strftime('%Y-%m-%d %H:%M:%S')}")
print(f"⏱️ Total duration: {format_duration(overall)}")


# Properly close the connection
cursor.close()
connection.close()
print("🔴 Ligação encerrada com sucesso!")
# Out:
# 🚀 Process started at: 2025-06-09 12:28:15
#
# 🌍 Processing airport 1/438: BRU
# ✅ Departure flights fetched successfully for BRU.
# ✅ Arrival flights fetched successfully for BRU.
# ✅ 125 new departure flights saved to the database.
# ✅ 53 new arrival flights saved to the database.
# ✅ Completed 1/438
# ⏱️ 21s since last • 21s total
# ----------------------------------------
#
# 🌍 Processing airport 2/438: CRL
# ✅ Departure flights fetched successfully for CRL.
# ✅ Arrival flights fetched successfully for CRL.
# ✅ 15 new departure flights saved to the database.
# ✅ 4 new arrival flights saved to the database.
# ✅ Completed 2/438
# ⏱️ 4s since last • 25s total
# ----------------------------------------
#
# 🌍 Processing airport 3/438: LGG
# ✅ Departure flights fetched successfully for LGG.
# ✅ Arrival flights fetched successfully for LGG.
# ✅ 4 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 3/438
# ⏱️ 2s since last • 27s total
# ----------------------------------------
#
# 🌍 Processing airport 4/438: OST
# ✅ Departure flights fetched successfully for OST.
# ✅ Arrival flights fetched successfully for OST.
# ✅ 0 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 4/438
# ⏱️ 1s since last • 28s total
# ----------------------------------------
#
# 🌍 Processing airport 5/438: AJA
# ✅ Departure flights fetched successfully for AJA.
# ✅ Arrival flights fetched successfully for AJA.
# ✅ 8 new departure flights saved to the database.
# ✅ 4 new arrival flights saved to the database.
# ✅ Completed 5/438
# ⏱️ 2s since last • 31s total
# ----------------------------------------
#
# 🌍 Processing airport 6/438: BIA
# ✅ Departure flights fetched successfully for BIA.
# ✅ Arrival flights fetched successfully for BIA.
# ✅ 7 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 6/438
# ⏱️ 2s since last • 33s total
# ----------------------------------------
#
# 🌍 Processing airport 7/438: BVA
# ✅ Departure flights fetched successfully for BVA.
# ✅ Arrival flights fetched successfully for BVA.
# ✅ 3 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 7/438
# ⏱️ 2s since last • 36s total
# ----------------------------------------
#
# 🌍 Processing airport 8/438: EGC
# ✅ Departure flights fetched successfully for EGC.
# ✅ Arrival flights fetched successfully for EGC.
# ✅ 2 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 8/438
# ⏱️ 1s since last • 37s total
# ----------------------------------------
#
# 🌍 Processing airport 9/438: BZR
# ✅ Departure flights fetched successfully for BZR.
# ✅ Arrival flights fetched successfully for BZR.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 9/438
# ⏱️ 0s since last • 38s total
# ----------------------------------------
#
# 🌍 Processing airport 10/438: BIQ
# ✅ Departure flights fetched successfully for BIQ.
# ✅ Arrival flights fetched successfully for BIQ.
# ✅ 4 new departure flights saved to the database.
# ✅ 7 new arrival flights saved to the database.
# ✅ Completed 10/438
# ⏱️ 2s since last • 40s total
# ----------------------------------------
#
# 🌍 Processing airport 11/438: BOD
# ✅ Departure flights fetched successfully for BOD.
# ✅ Arrival flights fetched successfully for BOD.
# ✅ 27 new departure flights saved to the database.
# ✅ 30 new arrival flights saved to the database.
# ✅ Completed 11/438
# ⏱️ 6s since last • 46s total
# ----------------------------------------
#
# 🌍 Processing airport 12/438: BES
# ✅ Departure flights fetched successfully for BES.
# ✅ Arrival flights fetched successfully for BES.
# ✅ 2 new departure flights saved to the database.
# ✅ 6 new arrival flights saved to the database.
# ✅ Completed 12/438
# ⏱️ 2s since last • 49s total
# ----------------------------------------
#
# 🌍 Processing airport 13/438: CCF
# ✅ Departure flights fetched successfully for CCF.
# ✅ Arrival flights fetched successfully for CCF.
# ✅ 1 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 13/438
# ⏱️ 1s since last • 50s total
# ----------------------------------------
#
# 🌍 Processing airport 14/438: XCR
# ✅ Departure flights fetched successfully for XCR.
# ✅ Arrival flights fetched successfully for XCR.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 14/438
# ⏱️ 0s since last • 51s total
# ----------------------------------------
#
# 🌍 Processing airport 15/438: CMF
# ✅ Departure flights fetched successfully for CMF.
# ✅ Arrival flights fetched successfully for CMF.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 15/438
# ⏱️ 0s since last • 52s total
# ----------------------------------------
#
# 🌍 Processing airport 16/438: DNR
# ✅ Departure flights fetched successfully for DNR.
# ✅ Arrival flights fetched successfully for DNR.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 16/438
# ⏱️ 0s since last • 52s total
# ----------------------------------------
#
# 🌍 Processing airport 17/438: FSC
# ✅ Departure flights fetched successfully for FSC.
# ✅ Arrival flights fetched successfully for FSC.
# ✅ 3 new departure flights saved to the database.
# ✅ 3 new arrival flights saved to the database.
# ✅ Completed 17/438
# ⏱️ 2s since last • 54s total
# ----------------------------------------
#
# 🌍 Processing airport 18/438: GNB
# ✅ Departure flights fetched successfully for GNB.
# ✅ Arrival flights fetched successfully for GNB.
# ✅ 0 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 18/438
# ⏱️ 1s since last • 56s total
# ----------------------------------------
#
# 🌍 Processing airport 19/438: LRH
# ✅ Departure flights fetched successfully for LRH.
# ✅ Arrival flights fetched successfully for LRH.
# ✅ 1 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 19/438
# ⏱️ 1s since last • 57s total
# ----------------------------------------
#
# 🌍 Processing airport 20/438: LIL
# ✅ Departure flights fetched successfully for LIL.
# ✅ Arrival flights fetched successfully for LIL.
# ✅ 4 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 20/438
# ⏱️ 1s since last • 59s total
# ----------------------------------------
#
# 🌍 Processing airport 21/438: LIG
# ✅ Departure flights fetched successfully for LIG.
# ✅ Arrival flights fetched successfully for LIG.
# ✅ 3 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 21/438
# ⏱️ 1s since last • 1m 0s total
# ----------------------------------------
#
# 🌍 Processing airport 22/438: LYS
# ✅ Departure flights fetched successfully for LYS.
# ✅ Arrival flights fetched successfully for LYS.
# ✅ 36 new departure flights saved to the database.
# ✅ 23 new arrival flights saved to the database.
# ✅ Completed 22/438
# ⏱️ 8s since last • 1m 8s total
# ----------------------------------------
#
# 🌍 Processing airport 23/438: MRS
# ✅ Departure flights fetched successfully for MRS.
# ✅ Arrival flights fetched successfully for MRS.
# ✅ 49 new departure flights saved to the database.
# ✅ 39 new arrival flights saved to the database.
# ✅ Completed 23/438
# ⏱️ 9s since last • 1m 18s total
# ----------------------------------------
#
# 🌍 Processing airport 24/438: BSL
# ✅ Departure flights fetched successfully for BSL.
# ✅ Arrival flights fetched successfully for BSL.
# ✅ 23 new departure flights saved to the database.
# ✅ 22 new arrival flights saved to the database.
# ✅ Completed 24/438
# ⏱️ 8s since last • 1m 27s total
# ----------------------------------------
#
# 🌍 Processing airport 25/438: NTE
# ✅ Departure flights fetched successfully for NTE.
# ✅ Arrival flights fetched successfully for NTE.
# ✅ 24 new departure flights saved to the database.
# ✅ 15 new arrival flights saved to the database.
# ✅ Completed 25/438
# ⏱️ 6s since last • 1m 33s total
# ----------------------------------------
#
# 🌍 Processing airport 26/438: NCE
# ✅ Departure flights fetched successfully for NCE.
# ✅ Arrival flights fetched successfully for NCE.
# ✅ 73 new departure flights saved to the database.
# ✅ 44 new arrival flights saved to the database.
# ✅ Completed 26/438
# ⏱️ 15s since last • 1m 49s total
# ----------------------------------------
#
# 🌍 Processing airport 27/438: FNI
# ✅ Departure flights fetched successfully for FNI.
# ✅ Arrival flights fetched successfully for FNI.
# ✅ 0 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 27/438
# ⏱️ 1s since last • 1m 51s total
# ----------------------------------------
#
# 🌍 Processing airport 28/438: CDG
# ✅ Departure flights fetched successfully for CDG.
# ✅ Arrival flights fetched successfully for CDG.
# ✅ 298 new departure flights saved to the database.
# ✅ 124 new arrival flights saved to the database.
# ✅ Completed 28/438
# ⏱️ 52s since last • 2m 43s total
# ----------------------------------------
#
# 🌍 Processing airport 29/438: ORY
# ✅ Departure flights fetched successfully for ORY.
# ✅ Arrival flights fetched successfully for ORY.
# ✅ 90 new departure flights saved to the database.
# ✅ 31 new arrival flights saved to the database.
# ✅ Completed 29/438
# ⏱️ 14s since last • 2m 57s total
# ----------------------------------------
#
# 🌍 Processing airport 30/438: PUF
# ✅ Departure flights fetched successfully for PUF.
# ✅ Arrival flights fetched successfully for PUF.
# ✅ 1 new departure flights saved to the database.
# ✅ 5 new arrival flights saved to the database.
# ✅ Completed 30/438
# ⏱️ 1s since last • 2m 59s total
# ----------------------------------------
#
# 🌍 Processing airport 31/438: PGF
# ✅ Departure flights fetched successfully for PGF.
# ✅ Arrival flights fetched successfully for PGF.
# ✅ 2 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 31/438
# ⏱️ 1s since last • 3m 1s total
# ----------------------------------------
#
# 🌍 Processing airport 32/438: PIS
# ✅ Departure flights fetched successfully for PIS.
# ✅ Arrival flights fetched successfully for PIS.
# ✅ 0 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 32/438
# ⏱️ 1s since last • 3m 2s total
# ----------------------------------------
#
# 🌍 Processing airport 33/438: RDZ
# ✅ Departure flights fetched successfully for RDZ.
# ✅ Arrival flights fetched successfully for RDZ.
# ✅ 2 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 33/438
# ⏱️ 1s since last • 3m 3s total
# ----------------------------------------
#
# 🌍 Processing airport 34/438: EBU
# ✅ Departure flights fetched successfully for EBU.
# ✅ Arrival flights fetched successfully for EBU.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 34/438
# ⏱️ 0s since last • 3m 4s total
# ----------------------------------------
#
# 🌍 Processing airport 35/438: SXB
# ✅ Departure flights fetched successfully for SXB.
# ✅ Arrival flights fetched successfully for SXB.
# ✅ 4 new departure flights saved to the database.
# ✅ 4 new arrival flights saved to the database.
# ✅ Completed 35/438
# ⏱️ 1s since last • 3m 6s total
# ----------------------------------------
#
# 🌍 Processing airport 36/438: TLN
# ✅ Departure flights fetched successfully for TLN.
# ✅ Arrival flights fetched successfully for TLN.
# ✅ 4 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 36/438
# ⏱️ 1s since last • 3m 7s total
# ----------------------------------------
#
# 🌍 Processing airport 37/438: TLS
# ✅ Departure flights fetched successfully for TLS.
# ✅ Arrival flights fetched successfully for TLS.
# ✅ 21 new departure flights saved to the database.
# ✅ 12 new arrival flights saved to the database.
# ✅ Completed 37/438
# ⏱️ 7s since last • 3m 15s total
# ----------------------------------------
#
# 🌍 Processing airport 38/438: TUF
# ✅ Departure flights fetched successfully for TUF.
# ✅ Arrival flights fetched successfully for TUF.
# ✅ 0 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 38/438
# ⏱️ 1s since last • 3m 16s total
# ----------------------------------------
#
# 🌍 Processing airport 39/438: GIB
# ✅ Departure flights fetched successfully for GIB.
# ✅ Arrival flights fetched successfully for GIB.
# ✅ 5 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 39/438
# ⏱️ 1s since last • 3m 17s total
# ----------------------------------------
#
# 🌍 Processing airport 40/438: GCI
# ✅ Departure flights fetched successfully for GCI.
# ✅ Arrival flights fetched successfully for GCI.
# ✅ 8 new departure flights saved to the database.
# ✅ 9 new arrival flights saved to the database.
# ✅ Completed 40/438
# ⏱️ 3s since last • 3m 20s total
# ----------------------------------------
#
# 🌍 Processing airport 41/438: JER
# ✅ Departure flights fetched successfully for JER.
# ✅ Arrival flights fetched successfully for JER.
# ✅ 11 new departure flights saved to the database.
# ✅ 14 new arrival flights saved to the database.
# ✅ Completed 41/438
# ⏱️ 3s since last • 3m 24s total
# ----------------------------------------
#
# 🌍 Processing airport 42/438: ORK
# ✅ Departure flights fetched successfully for ORK.
# ✅ Arrival flights fetched successfully for ORK.
# ✅ 9 new departure flights saved to the database.
# ✅ 5 new arrival flights saved to the database.
# ✅ Completed 42/438
# ⏱️ 2s since last • 3m 27s total
# ----------------------------------------
#
# 🌍 Processing airport 43/438: DUB
# ✅ Departure flights fetched successfully for DUB.
# ✅ Arrival flights fetched successfully for DUB.
# ✅ 116 new departure flights saved to the database.
# ✅ 71 new arrival flights saved to the database.
# ✅ Completed 43/438
# ⏱️ 22s since last • 3m 50s total
# ----------------------------------------
#
# 🌍 Processing airport 44/438: KIR
# ✅ Departure flights fetched successfully for KIR.
# ✅ Arrival flights fetched successfully for KIR.
# ✅ 1 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 44/438
# ⏱️ 1s since last • 3m 51s total
# ----------------------------------------
#
# 🌍 Processing airport 45/438: NOC
# ✅ Departure flights fetched successfully for NOC.
# ✅ Arrival flights fetched successfully for NOC.
# ✅ 1 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 45/438
# ⏱️ 1s since last • 3m 52s total
# ----------------------------------------
#
# 🌍 Processing airport 46/438: SNN
# ✅ Departure flights fetched successfully for SNN.
# ✅ Arrival flights fetched successfully for SNN.
# ✅ 8 new departure flights saved to the database.
# ✅ 7 new arrival flights saved to the database.
# ✅ Completed 46/438
# ⏱️ 2s since last • 3m 55s total
# ----------------------------------------
#
# 🌍 Processing airport 47/438: IOM
# ✅ Departure flights fetched successfully for IOM.
# ✅ Arrival flights fetched successfully for IOM.
# ✅ 3 new departure flights saved to the database.
# ✅ 3 new arrival flights saved to the database.
# ✅ Completed 47/438
# ⏱️ 2s since last • 3m 57s total
# ----------------------------------------
#
# 🌍 Processing airport 48/438: LUX
# ✅ Departure flights fetched successfully for LUX.
# ✅ Arrival flights fetched successfully for LUX.
# ✅ 19 new departure flights saved to the database.
# ✅ 18 new arrival flights saved to the database.
# ✅ Completed 48/438
# ⏱️ 6s since last • 4m 3s total
# ----------------------------------------
#
# 🌍 Processing airport 49/438: AMS
# ✅ Departure flights fetched successfully for AMS.
# ✅ Arrival flights fetched successfully for AMS.
# ✅ 313 new departure flights saved to the database.
# ✅ 189 new arrival flights saved to the database.
# ✅ Completed 49/438
# ⏱️ 52s since last • 4m 56s total
# ----------------------------------------
#
# 🌍 Processing airport 50/438: EIN
# ✅ Departure flights fetched successfully for EIN.
# ✅ Arrival flights fetched successfully for EIN.
# ✅ 8 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 50/438
# ⏱️ 3s since last • 4m 59s total
# ----------------------------------------
#
# 🌍 Processing airport 51/438: GRQ
# ✅ Departure flights fetched successfully for GRQ.
# ✅ Arrival flights fetched successfully for GRQ.
# ✅ 3 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 51/438
# ⏱️ 1s since last • 5m 1s total
# ----------------------------------------
#
# 🌍 Processing airport 52/438: MST
# ✅ Departure flights fetched successfully for MST.
# ✅ Arrival flights fetched successfully for MST.
# ✅ 3 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 52/438
# ⏱️ 1s since last • 5m 2s total
# ----------------------------------------
#
# 🌍 Processing airport 53/438: RTM
# ✅ Departure flights fetched successfully for RTM.
# ✅ Arrival flights fetched successfully for RTM.
# ✅ 4 new departure flights saved to the database.
# ✅ 4 new arrival flights saved to the database.
# ✅ Completed 53/438
# ⏱️ 2s since last • 5m 4s total
# ----------------------------------------
#
# 🌍 Processing airport 54/438: BYJ
# ✅ Departure flights fetched successfully for BYJ.
# ✅ Arrival flights fetched successfully for BYJ.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 54/438
# ⏱️ 0s since last • 5m 5s total
# ----------------------------------------
#
# 🌍 Processing airport 55/438: FAO
# ✅ Departure flights fetched successfully for FAO.
# ✅ Arrival flights fetched successfully for FAO.
# ✅ 11 new departure flights saved to the database.
# ✅ 14 new arrival flights saved to the database.
# ✅ Completed 55/438
# ⏱️ 5s since last • 5m 10s total
# ----------------------------------------
#
# 🌍 Processing airport 56/438: FNC
# ✅ Departure flights fetched successfully for FNC.
# ✅ Arrival flights fetched successfully for FNC.
# ✅ 14 new departure flights saved to the database.
# ✅ 3 new arrival flights saved to the database.
# ✅ Completed 56/438
# ⏱️ 4s since last • 5m 15s total
# ----------------------------------------
#
# 🌍 Processing airport 57/438: PXO
# ✅ Departure flights fetched successfully for PXO.
# ✅ Arrival flights fetched successfully for PXO.
# ✅ 0 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 57/438
# ⏱️ 1s since last • 5m 16s total
# ----------------------------------------
#
# 🌍 Processing airport 58/438: LIS
# ✅ Departure flights fetched successfully for LIS.
# ✅ Arrival flights fetched successfully for LIS.
# ✅ 111 new departure flights saved to the database.
# ✅ 29 new arrival flights saved to the database.
# ✅ Completed 58/438
# ⏱️ 21s since last • 5m 37s total
# ----------------------------------------
#
# 🌍 Processing airport 59/438: OPO
# ✅ Departure flights fetched successfully for OPO.
# ✅ Arrival flights fetched successfully for OPO.
# ✅ 52 new departure flights saved to the database.
# ✅ 18 new arrival flights saved to the database.
# ✅ Completed 59/438
# ⏱️ 10s since last • 5m 48s total
# ----------------------------------------
#
# 🌍 Processing airport 60/438: PDL
# ✅ Departure flights fetched successfully for PDL.
# ✅ Arrival flights fetched successfully for PDL.
# ✅ 12 new departure flights saved to the database.
# ✅ 8 new arrival flights saved to the database.
# ✅ Completed 60/438
# ⏱️ 3s since last • 5m 52s total
# ----------------------------------------
#
# 🌍 Processing airport 61/438: TER
# ✅ Departure flights fetched successfully for TER.
# ✅ Arrival flights fetched successfully for TER.
# ✅ 4 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 61/438
# ⏱️ 2s since last • 5m 54s total
# ----------------------------------------
#
# 🌍 Processing airport 62/438: LCG
# ✅ Departure flights fetched successfully for LCG.
# ✅ Arrival flights fetched successfully for LCG.
# ✅ 8 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 62/438
# ⏱️ 2s since last • 5m 57s total
# ----------------------------------------
#
# 🌍 Processing airport 63/438: ALC
# ✅ Departure flights fetched successfully for ALC.
# ✅ Arrival flights fetched successfully for ALC.
# ✅ 30 new departure flights saved to the database.
# ✅ 12 new arrival flights saved to the database.
# ✅ Completed 63/438
# ⏱️ 9s since last • 6m 6s total
# ----------------------------------------
#
# 🌍 Processing airport 64/438: LEI
# ✅ Departure flights fetched successfully for LEI.
# ✅ Arrival flights fetched successfully for LEI.
# ✅ 1 new departure flights saved to the database.
# ✅ 3 new arrival flights saved to the database.
# ✅ Completed 64/438
# ⏱️ 1s since last • 6m 8s total
# ----------------------------------------
#
# 🌍 Processing airport 65/438: OVD
# ✅ Departure flights fetched successfully for OVD.
# ✅ Arrival flights fetched successfully for OVD.
# ✅ 8 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 65/438
# ⏱️ 2s since last • 6m 11s total
# ----------------------------------------
#
# 🌍 Processing airport 66/438: BCN
# ✅ Departure flights fetched successfully for BCN.
# ✅ Arrival flights fetched successfully for BCN.
# ✅ 119 new departure flights saved to the database.
# ✅ 53 new arrival flights saved to the database.
# ✅ Completed 66/438
# ⏱️ 28s since last • 6m 39s total
# ----------------------------------------
#
# 🌍 Processing airport 67/438: FUE
# ✅ Departure flights fetched successfully for FUE.
# ✅ Arrival flights fetched successfully for FUE.
# ✅ 18 new departure flights saved to the database.
# ✅ 10 new arrival flights saved to the database.
# ✅ Completed 67/438
# ⏱️ 4s since last • 6m 43s total
# ----------------------------------------
#
# 🌍 Processing airport 68/438: GRO
# ✅ Departure flights fetched successfully for GRO.
# ✅ Arrival flights fetched successfully for GRO.
# ✅ 4 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 68/438
# ⏱️ 2s since last • 6m 45s total
# ----------------------------------------
#
# 🌍 Processing airport 69/438: LPA
# ✅ Departure flights fetched successfully for LPA.
# ✅ Arrival flights fetched successfully for LPA.
# ✅ 48 new departure flights saved to the database.
# ✅ 26 new arrival flights saved to the database.
# ✅ Completed 69/438
# ⏱️ 9s since last • 6m 55s total
# ----------------------------------------
#
# 🌍 Processing airport 70/438: GRX
# ✅ Departure flights fetched successfully for GRX.
# ✅ Arrival flights fetched successfully for GRX.
# ✅ 6 new departure flights saved to the database.
# ✅ 6 new arrival flights saved to the database.
# ✅ Completed 70/438
# ⏱️ 2s since last • 6m 57s total
# ----------------------------------------
#
# 🌍 Processing airport 71/438: HSK
# ✅ Departure flights fetched successfully for HSK.
# ✅ Arrival flights fetched successfully for HSK.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 71/438
# ⏱️ 0s since last • 6m 57s total
# ----------------------------------------
#
# 🌍 Processing airport 72/438: IBZ
# ✅ Departure flights fetched successfully for IBZ.
# ✅ Arrival flights fetched successfully for IBZ.
# ✅ 32 new departure flights saved to the database.
# ✅ 21 new arrival flights saved to the database.
# ✅ Completed 72/438
# ⏱️ 8s since last • 7m 6s total
# ----------------------------------------
#
# 🌍 Processing airport 73/438: XRY
# ✅ Departure flights fetched successfully for XRY.
# ✅ Arrival flights fetched successfully for XRY.
# ✅ 6 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 73/438
# ⏱️ 2s since last • 7m 8s total
# ----------------------------------------
#
# 🌍 Processing airport 74/438: SPC
# ✅ Departure flights fetched successfully for SPC.
# ✅ Arrival flights fetched successfully for SPC.
# ✅ 3 new departure flights saved to the database.
# ✅ 4 new arrival flights saved to the database.
# ✅ Completed 74/438
# ⏱️ 2s since last • 7m 10s total
# ----------------------------------------
#
# 🌍 Processing airport 75/438: ACE
# ✅ Departure flights fetched successfully for ACE.
# ✅ Arrival flights fetched successfully for ACE.
# ✅ 4 new departure flights saved to the database.
# ✅ 8 new arrival flights saved to the database.
# ✅ Completed 75/438
# ⏱️ 3s since last • 7m 14s total
# ----------------------------------------
#
# 🌍 Processing airport 76/438: ILD
# ✅ Departure flights fetched successfully for ILD.
# ✅ Arrival flights fetched successfully for ILD.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 76/438
# ⏱️ 0s since last • 7m 15s total
# ----------------------------------------
#
# 🌍 Processing airport 77/438: MAD
# ✅ Departure flights fetched successfully for MAD.
# ✅ Arrival flights fetched successfully for MAD.
# ✅ 123 new departure flights saved to the database.
# ✅ 111 new arrival flights saved to the database.
# ✅ Completed 77/438
# ⏱️ 37s since last • 7m 53s total
# ----------------------------------------
#
# 🌍 Processing airport 78/438: AGP
# ✅ Departure flights fetched successfully for AGP.
# ✅ Arrival flights fetched successfully for AGP.
# ✅ 59 new departure flights saved to the database.
# ✅ 43 new arrival flights saved to the database.
# ✅ Completed 78/438
# ⏱️ 13s since last • 8m 6s total
# ----------------------------------------
#
# 🌍 Processing airport 79/438: MAH
# ✅ Departure flights fetched successfully for MAH.
# ✅ Arrival flights fetched successfully for MAH.
# ✅ 13 new departure flights saved to the database.
# ✅ 9 new arrival flights saved to the database.
# ✅ Completed 79/438
# ⏱️ 3s since last • 8m 10s total
# ----------------------------------------
#
# 🌍 Processing airport 80/438: MJV
# ✅ Departure flights fetched successfully for MJV.
# ✅ Arrival flights fetched successfully for MJV.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 80/438
# ⏱️ 0s since last • 8m 11s total
# ----------------------------------------
#
# 🌍 Processing airport 81/438: PMI
# ✅ Departure flights fetched successfully for PMI.
# ✅ Arrival flights fetched successfully for PMI.
# ✅ 70 new departure flights saved to the database.
# ✅ 36 new arrival flights saved to the database.
# ✅ Completed 81/438
# ⏱️ 16s since last • 8m 27s total
# ----------------------------------------
#
# 🌍 Processing airport 82/438: REU
# ✅ Departure flights fetched successfully for REU.
# ✅ Arrival flights fetched successfully for REU.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 82/438
# ⏱️ 0s since last • 8m 28s total
# ----------------------------------------
#
# 🌍 Processing airport 83/438: SDR
# ✅ Departure flights fetched successfully for SDR.
# ✅ Arrival flights fetched successfully for SDR.
# ✅ 7 new departure flights saved to the database.
# ✅ 3 new arrival flights saved to the database.
# ✅ Completed 83/438
# ⏱️ 2s since last • 8m 30s total
# ----------------------------------------
#
# 🌍 Processing airport 84/438: SCQ
# ✅ Departure flights fetched successfully for SCQ.
# ✅ Arrival flights fetched successfully for SCQ.
# ✅ 4 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 84/438
# ⏱️ 2s since last • 8m 33s total
# ----------------------------------------
#
# 🌍 Processing airport 85/438: SVQ
# ✅ Departure flights fetched successfully for SVQ.
# ✅ Arrival flights fetched successfully for SVQ.
# ✅ 19 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 85/438
# ⏱️ 5s since last • 8m 38s total
# ----------------------------------------
#
# 🌍 Processing airport 86/438: TFN
# ✅ Departure flights fetched successfully for TFN.
# ✅ Arrival flights fetched successfully for TFN.
# ✅ 20 new departure flights saved to the database.
# ✅ 13 new arrival flights saved to the database.
# ✅ Completed 86/438
# ⏱️ 7s since last • 8m 45s total
# ----------------------------------------
#
# 🌍 Processing airport 87/438: TFS
# ✅ Departure flights fetched successfully for TFS.
# ✅ Arrival flights fetched successfully for TFS.
# ✅ 17 new departure flights saved to the database.
# ✅ 6 new arrival flights saved to the database.
# ✅ Completed 87/438
# ⏱️ 3s since last • 8m 49s total
# ----------------------------------------
#
# 🌍 Processing airport 88/438: VLC
# ✅ Departure flights fetched successfully for VLC.
# ✅ Arrival flights fetched successfully for VLC.
# ✅ 33 new departure flights saved to the database.
# ✅ 11 new arrival flights saved to the database.
# ✅ Completed 88/438
# ⏱️ 6s since last • 8m 56s total
# ----------------------------------------
#
# 🌍 Processing airport 89/438: VLL
# ✅ Departure flights fetched successfully for VLL.
# ✅ Arrival flights fetched successfully for VLL.
# ✅ 0 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 89/438
# ⏱️ 1s since last • 8m 57s total
# ----------------------------------------
#
# 🌍 Processing airport 90/438: ZAZ
# ✅ Departure flights fetched successfully for ZAZ.
# ✅ Arrival flights fetched successfully for ZAZ.
# ✅ 2 new departure flights saved to the database.
# ✅ 3 new arrival flights saved to the database.
# ✅ Completed 90/438
# ⏱️ 1s since last • 8m 58s total
# ----------------------------------------
#
# 🌍 Processing airport 91/438: GRZ
# ✅ Departure flights fetched successfully for GRZ.
# ✅ Arrival flights fetched successfully for GRZ.
# ✅ 2 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 91/438
# ⏱️ 2s since last • 9m 0s total
# ----------------------------------------
#
# 🌍 Processing airport 92/438: KLU
# ✅ Departure flights fetched successfully for KLU.
# ✅ Arrival flights fetched successfully for KLU.
# ✅ 0 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 92/438
# ⏱️ 1s since last • 9m 2s total
# ----------------------------------------
#
# 🌍 Processing airport 93/438: INN
# ✅ Departure flights fetched successfully for INN.
# ✅ Arrival flights fetched successfully for INN.
# ✅ 5 new departure flights saved to the database.
# ✅ 6 new arrival flights saved to the database.
# ✅ Completed 93/438
# ⏱️ 1s since last • 9m 4s total
# ----------------------------------------
#
# 🌍 Processing airport 94/438: LNZ
# ✅ Departure flights fetched successfully for LNZ.
# ✅ Arrival flights fetched successfully for LNZ.
# ✅ 2 new departure flights saved to the database.
# ✅ 4 new arrival flights saved to the database.
# ✅ Completed 94/438
# ⏱️ 1s since last • 9m 5s total
# ----------------------------------------
#
# 🌍 Processing airport 95/438: SZG
# ✅ Departure flights fetched successfully for SZG.
# ✅ Arrival flights fetched successfully for SZG.
# ✅ 6 new departure flights saved to the database.
# ✅ 9 new arrival flights saved to the database.
# ✅ Completed 95/438
# ⏱️ 2s since last • 9m 8s total
# ----------------------------------------
#
# 🌍 Processing airport 96/438: VIE
# ✅ Departure flights fetched successfully for VIE.
# ⚠️ [VIE] Attempt 1/3 failed: HTTPError('404 Client Error: Not Found for url: https://aviation-edge.com/v2/public/timetable?key=abcf21-5fbf11&iataCode=VIE&type=arrival')
#    ↳ retrying in 1s…
# ✅ Arrival flights fetched successfully for VIE.
# ✅ 76 new departure flights saved to the database.
# ✅ 54 new arrival flights saved to the database.
# ✅ Completed 96/438
# ⏱️ 23s since last • 9m 31s total
# ----------------------------------------
#
# 🌍 Processing airport 97/438: FKB
# ✅ Departure flights fetched successfully for FKB.
# ✅ Arrival flights fetched successfully for FKB.
# ✅ 4 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 97/438
# ⏱️ 2s since last • 9m 33s total
# ----------------------------------------
#
# 🌍 Processing airport 98/438: TXL
# ✅ Departure flights fetched successfully for TXL.
# ✅ Arrival flights fetched successfully for TXL.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 98/438
# ⏱️ 0s since last • 9m 34s total
# ----------------------------------------
#
# 🌍 Processing airport 99/438: SXF
# ✅ Departure flights fetched successfully for SXF.
# ✅ Arrival flights fetched successfully for SXF.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 99/438
# ⏱️ 0s since last • 9m 35s total
# ----------------------------------------
#
# 🌍 Processing airport 100/438: BER
# ✅ Departure flights fetched successfully for BER.
# ✅ Arrival flights fetched successfully for BER.
# ✅ 94 new departure flights saved to the database.
# ✅ 54 new arrival flights saved to the database.
# ✅ Completed 100/438
# ⏱️ 16s since last • 9m 51s total
# ----------------------------------------
#
# 🌍 Processing airport 101/438: BRE
# ✅ Departure flights fetched successfully for BRE.
# ✅ Arrival flights fetched successfully for BRE.
# ✅ 9 new departure flights saved to the database.
# ✅ 8 new arrival flights saved to the database.
# ✅ Completed 101/438
# ⏱️ 3s since last • 9m 55s total
# ----------------------------------------
#
# 🌍 Processing airport 102/438: CGN
# ✅ Departure flights fetched successfully for CGN.
# ✅ Arrival flights fetched successfully for CGN.
# ✅ 25 new departure flights saved to the database.
# ✅ 13 new arrival flights saved to the database.
# ✅ Completed 102/438
# ⏱️ 5s since last • 10m 0s total
# ----------------------------------------
#
# 🌍 Processing airport 103/438: DTM
# ✅ Departure flights fetched successfully for DTM.
# ✅ Arrival flights fetched successfully for DTM.
# ✅ 2 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 103/438
# ⏱️ 2s since last • 10m 2s total
# ----------------------------------------
#
# 🌍 Processing airport 104/438: DUS
# ✅ Departure flights fetched successfully for DUS.
# ✅ Arrival flights fetched successfully for DUS.
# ✅ 36 new departure flights saved to the database.
# ✅ 42 new arrival flights saved to the database.
# ✅ Completed 104/438
# ⏱️ 13s since last • 10m 16s total
# ----------------------------------------
#
# 🌍 Processing airport 105/438: FRA
# ✅ Departure flights fetched successfully for FRA.
# ✅ Arrival flights fetched successfully for FRA.
# ✅ 280 new departure flights saved to the database.
# ✅ 127 new arrival flights saved to the database.
# ✅ Completed 105/438
# ⏱️ 50s since last • 11m 6s total
# ----------------------------------------
#
# 🌍 Processing airport 106/438: HHN
# ✅ Departure flights fetched successfully for HHN.
# ✅ Arrival flights fetched successfully for HHN.
# ✅ 2 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 106/438
# ⏱️ 1s since last • 11m 8s total
# ----------------------------------------
#
# 🌍 Processing airport 107/438: MLH
# ✅ Departure flights fetched successfully for MLH.
# ✅ Arrival flights fetched successfully for MLH.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 107/438
# ⏱️ 0s since last • 11m 9s total
# ----------------------------------------
#
# 🌍 Processing airport 108/438: BSL
# ✅ Departure flights fetched successfully for BSL.
# ✅ Arrival flights fetched successfully for BSL.
# ✅ 0 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 108/438
# ⏱️ 6s since last • 11m 15s total
# ----------------------------------------
#
# 🌍 Processing airport 109/438: EAP
# ✅ Departure flights fetched successfully for EAP.
# ✅ Arrival flights fetched successfully for EAP.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 109/438
# ⏱️ 0s since last • 11m 16s total
# ----------------------------------------
#
# 🌍 Processing airport 110/438: FDH
# ✅ Departure flights fetched successfully for FDH.
# ✅ Arrival flights fetched successfully for FDH.
# ✅ 3 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 110/438
# ⏱️ 1s since last • 11m 17s total
# ----------------------------------------
#
# 🌍 Processing airport 111/438: HAM
# ⚠️ [HAM] Attempt 1/3 failed: HTTPError('404 Client Error: Not Found for url: https://aviation-edge.com/v2/public/timetable?key=abcf21-5fbf11&iataCode=HAM&type=departure')
#    ↳ retrying in 1s…
# ✅ Departure flights fetched successfully for HAM.
# ✅ Arrival flights fetched successfully for HAM.
# ✅ 47 new departure flights saved to the database.
# ✅ 41 new arrival flights saved to the database.
# ✅ Completed 111/438
# ⏱️ 14s since last • 11m 32s total
# ----------------------------------------
#
# 🌍 Processing airport 112/438: HAJ
# ✅ Departure flights fetched successfully for HAJ.
# ✅ Arrival flights fetched successfully for HAJ.
# ✅ 21 new departure flights saved to the database.
# ✅ 17 new arrival flights saved to the database.
# ✅ Completed 112/438
# ⏱️ 5s since last • 11m 37s total
# ----------------------------------------
#
# 🌍 Processing airport 113/438: LEJ
# ✅ Departure flights fetched successfully for LEJ.
# ✅ Arrival flights fetched successfully for LEJ.
# ✅ 15 new departure flights saved to the database.
# ✅ 8 new arrival flights saved to the database.
# ✅ Completed 113/438
# ⏱️ 3s since last • 11m 41s total
# ----------------------------------------
#
# 🌍 Processing airport 114/438: LBC
# ✅ Departure flights fetched successfully for LBC.
# ✅ Arrival flights fetched successfully for LBC.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 114/438
# ⏱️ 0s since last • 11m 42s total
# ----------------------------------------
#
# 🌍 Processing airport 115/438: FMM
# ✅ Departure flights fetched successfully for FMM.
# ✅ Arrival flights fetched successfully for FMM.
# ✅ 5 new departure flights saved to the database.
# ✅ 4 new arrival flights saved to the database.
# ✅ Completed 115/438
# ⏱️ 2s since last • 11m 44s total
# ----------------------------------------
#
# 🌍 Processing airport 116/438: MUC
# ✅ Departure flights fetched successfully for MUC.
# ✅ Arrival flights fetched successfully for MUC.
# ✅ 88 new departure flights saved to the database.
# ✅ 73 new arrival flights saved to the database.
# ✅ Completed 116/438
# ⏱️ 31s since last • 12m 16s total
# ----------------------------------------
#
# 🌍 Processing airport 117/438: NUE
# ✅ Departure flights fetched successfully for NUE.
# ✅ Arrival flights fetched successfully for NUE.
# ✅ 21 new departure flights saved to the database.
# ✅ 15 new arrival flights saved to the database.
# ✅ Completed 117/438
# ⏱️ 4s since last • 12m 20s total
# ----------------------------------------
#
# 🌍 Processing airport 118/438: STR
# ✅ Departure flights fetched successfully for STR.
# ✅ Arrival flights fetched successfully for STR.
# ✅ 31 new departure flights saved to the database.
# ✅ 16 new arrival flights saved to the database.
# ✅ Completed 118/438
# ⏱️ 7s since last • 12m 28s total
# ----------------------------------------
#
# 🌍 Processing airport 119/438: NRN
# ✅ Departure flights fetched successfully for NRN.
# ✅ Arrival flights fetched successfully for NRN.
# ✅ 4 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 119/438
# ⏱️ 1s since last • 12m 30s total
# ----------------------------------------
#
# 🌍 Processing airport 120/438: ATH
# ✅ Departure flights fetched successfully for ATH.
# ✅ Arrival flights fetched successfully for ATH.
# ✅ 73 new departure flights saved to the database.
# ✅ 74 new arrival flights saved to the database.
# ✅ Completed 120/438
# ⏱️ 24s since last • 12m 54s total
# ----------------------------------------
#
# 🌍 Processing airport 121/438: CHQ
# ⚠️ [CHQ] Attempt 1/3 failed: HTTPError('404 Client Error: Not Found for url: https://aviation-edge.com/v2/public/timetable?key=abcf21-5fbf11&iataCode=CHQ&type=departure')
#    ↳ retrying in 1s…
# ✅ Departure flights fetched successfully for CHQ.
# ✅ Arrival flights fetched successfully for CHQ.
# ✅ 8 new departure flights saved to the database.
# ✅ 6 new arrival flights saved to the database.
# ✅ Completed 121/438
# ⏱️ 5s since last • 13m 0s total
# ----------------------------------------
#
# 🌍 Processing airport 122/438: JKH
# ✅ Departure flights fetched successfully for JKH.
# ✅ Arrival flights fetched successfully for JKH.
# ✅ 4 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 122/438
# ⏱️ 1s since last • 13m 2s total
# ----------------------------------------
#
# 🌍 Processing airport 123/438: CFU
# ✅ Departure flights fetched successfully for CFU.
# ✅ Arrival flights fetched successfully for CFU.
# ✅ 12 new departure flights saved to the database.
# ✅ 4 new arrival flights saved to the database.
# ✅ Completed 123/438
# ⏱️ 3s since last • 13m 6s total
# ----------------------------------------
#
# 🌍 Processing airport 124/438: HER
# ⚠️ [HER] Attempt 1/3 failed: HTTPError('404 Client Error: Not Found for url: https://aviation-edge.com/v2/public/timetable?key=abcf21-5fbf11&iataCode=HER&type=departure')
#    ↳ retrying in 1s…
# ✅ Departure flights fetched successfully for HER.
# ✅ Arrival flights fetched successfully for HER.
# ✅ 25 new departure flights saved to the database.
# ✅ 10 new arrival flights saved to the database.
# ✅ Completed 124/438
# ⏱️ 9s since last • 13m 15s total
# ----------------------------------------
#
# 🌍 Processing airport 125/438: KLX
# ✅ Departure flights fetched successfully for KLX.
# ✅ Arrival flights fetched successfully for KLX.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 125/438
# ⏱️ 0s since last • 13m 16s total
# ----------------------------------------
#
# 🌍 Processing airport 126/438: AOK
# ✅ Departure flights fetched successfully for AOK.
# ✅ Arrival flights fetched successfully for AOK.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 126/438
# ⏱️ 0s since last • 13m 16s total
# ----------------------------------------
#
# 🌍 Processing airport 127/438: KVA
# ✅ Departure flights fetched successfully for KVA.
# ✅ Arrival flights fetched successfully for KVA.
# ✅ 2 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 127/438
# ⏱️ 1s since last • 13m 18s total
# ----------------------------------------
#
# 🌍 Processing airport 128/438: EFL
# ✅ Departure flights fetched successfully for EFL.
# ✅ Arrival flights fetched successfully for EFL.
# ✅ 2 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 128/438
# ⏱️ 1s since last • 13m 20s total
# ----------------------------------------
#
# 🌍 Processing airport 129/438: KGS
# ✅ Departure flights fetched successfully for KGS.
# ✅ Arrival flights fetched successfully for KGS.
# ✅ 8 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 129/438
# ⏱️ 2s since last • 13m 22s total
# ----------------------------------------
#
# 🌍 Processing airport 130/438: JMK
# ✅ Departure flights fetched successfully for JMK.
# ✅ Arrival flights fetched successfully for JMK.
# ✅ 9 new departure flights saved to the database.
# ✅ 3 new arrival flights saved to the database.
# ✅ Completed 130/438
# ⏱️ 2s since last • 13m 25s total
# ----------------------------------------
#
# 🌍 Processing airport 131/438: MJT
# ✅ Departure flights fetched successfully for MJT.
# ✅ Arrival flights fetched successfully for MJT.
# ✅ 2 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 131/438
# ⏱️ 1s since last • 13m 26s total
# ----------------------------------------
#
# 🌍 Processing airport 132/438: PVK
# ✅ Departure flights fetched successfully for PVK.
# ✅ Arrival flights fetched successfully for PVK.
# ✅ 1 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 132/438
# ⏱️ 1s since last • 13m 28s total
# ----------------------------------------
#
# 🌍 Processing airport 133/438: RHO
# ✅ Departure flights fetched successfully for RHO.
# ✅ Arrival flights fetched successfully for RHO.
# ✅ 15 new departure flights saved to the database.
# ✅ 7 new arrival flights saved to the database.
# ✅ Completed 133/438
# ⏱️ 4s since last • 13m 32s total
# ----------------------------------------
#
# 🌍 Processing airport 134/438: SMI
# ✅ Departure flights fetched successfully for SMI.
# ✅ Arrival flights fetched successfully for SMI.
# ✅ 3 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 134/438
# ⏱️ 1s since last • 13m 34s total
# ----------------------------------------
#
# 🌍 Processing airport 135/438: JTR
# ✅ Departure flights fetched successfully for JTR.
# ✅ Arrival flights fetched successfully for JTR.
# ✅ 3 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 135/438
# ⏱️ 2s since last • 13m 36s total
# ----------------------------------------
#
# 🌍 Processing airport 136/438: JSI
# ✅ Departure flights fetched successfully for JSI.
# ✅ Arrival flights fetched successfully for JSI.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 136/438
# ⏱️ 0s since last • 13m 37s total
# ----------------------------------------
#
# 🌍 Processing airport 137/438: SKU
# ✅ Departure flights fetched successfully for SKU.
# ✅ Arrival flights fetched successfully for SKU.
# ✅ 0 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 137/438
# ⏱️ 1s since last • 13m 38s total
# ----------------------------------------
#
# 🌍 Processing airport 138/438: SKG
# ✅ Departure flights fetched successfully for SKG.
# ✅ Arrival flights fetched successfully for SKG.
# ...
# ----------------------------------------
#
# 🌍 Processing airport 393/438: TRF
# ✅ Departure flights fetched successfully for TRF.
# ✅ Arrival flights fetched successfully for TRF.
# ✅ 12 new departure flights saved to the database.
# ✅ 4 new arrival flights saved to the database.
# ✅ Completed 393/438
# ⏱️ 2s since last • 29m 42s total
# ----------------------------------------
#
# 🌍 Processing airport 394/438: SVG
# ✅ Departure flights fetched successfully for SVG.
# ✅ Arrival flights fetched successfully for SVG.
# ✅ 25 new departure flights saved to the database.
# ✅ 16 new arrival flights saved to the database.
# ✅ Completed 394/438
# ⏱️ 4s since last • 29m 46s total
# ----------------------------------------
#
# 🌍 Processing airport 395/438: TOS
# ✅ Departure flights fetched successfully for TOS.
# ✅ Arrival flights fetched successfully for TOS.
# ✅ 49 new departure flights saved to the database.
# ✅ 38 new arrival flights saved to the database.
# ✅ Completed 395/438
# ⏱️ 4s since last • 29m 51s total
# ----------------------------------------
#
# 🌍 Processing airport 396/438: TRD
# ✅ Departure flights fetched successfully for TRD.
# ✅ Arrival flights fetched successfully for TRD.
# ✅ 41 new departure flights saved to the database.
# ✅ 20 new arrival flights saved to the database.
# ✅ Completed 396/438
# ⏱️ 5s since last • 29m 57s total
# ----------------------------------------
#
# 🌍 Processing airport 397/438: GSE
# ✅ Departure flights fetched successfully for GSE.
# ✅ Arrival flights fetched successfully for GSE.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 397/438
# ⏱️ 0s since last • 29m 57s total
# ----------------------------------------
#
# 🌍 Processing airport 398/438: GOT
# ✅ Departure flights fetched successfully for GOT.
# ✅ Arrival flights fetched successfully for GOT.
# ✅ 79 new departure flights saved to the database.
# ✅ 68 new arrival flights saved to the database.
# ✅ Completed 398/438
# ⏱️ 8s since last • 30m 5s total
# ----------------------------------------
#
# 🌍 Processing airport 399/438: LLA
# ✅ Departure flights fetched successfully for LLA.
# ✅ Arrival flights fetched successfully for LLA.
# ✅ 29 new departure flights saved to the database.
# ✅ 19 new arrival flights saved to the database.
# ✅ Completed 399/438
# ⏱️ 2s since last • 30m 8s total
# ----------------------------------------
#
# 🌍 Processing airport 400/438: MMX
# ✅ Departure flights fetched successfully for MMX.
# ✅ Arrival flights fetched successfully for MMX.
# ✅ 20 new departure flights saved to the database.
# ✅ 12 new arrival flights saved to the database.
# ✅ Completed 400/438
# ⏱️ 2s since last • 30m 10s total
# ----------------------------------------
#
# 🌍 Processing airport 401/438: NRK
# ✅ Departure flights fetched successfully for NRK.
# ✅ Arrival flights fetched successfully for NRK.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 401/438
# ⏱️ 0s since last • 30m 11s total
# ----------------------------------------
#
# 🌍 Processing airport 402/438: OSD
# ✅ Departure flights fetched successfully for OSD.
# ✅ Arrival flights fetched successfully for OSD.
# ✅ 17 new departure flights saved to the database.
# ✅ 11 new arrival flights saved to the database.
# ✅ Completed 402/438
# ⏱️ 1s since last • 30m 13s total
# ----------------------------------------
#
# 🌍 Processing airport 403/438: ARN
# ✅ Departure flights fetched successfully for ARN.
# ✅ Arrival flights fetched successfully for ARN.
# ✅ 253 new departure flights saved to the database.
# ✅ 190 new arrival flights saved to the database.
# ✅ Completed 403/438
# ⏱️ 24s since last • 30m 37s total
# ----------------------------------------
#
# 🌍 Processing airport 404/438: BMA
# ✅ Departure flights fetched successfully for BMA.
# ✅ Arrival flights fetched successfully for BMA.
# ✅ 14 new departure flights saved to the database.
# ✅ 12 new arrival flights saved to the database.
# ✅ Completed 404/438
# ⏱️ 2s since last • 30m 39s total
# ----------------------------------------
#
# 🌍 Processing airport 405/438: NYO
# ✅ Departure flights fetched successfully for NYO.
# ✅ Arrival flights fetched successfully for NYO.
# ✅ 0 new departure flights saved to the database.
# ✅ 1 new arrival flights saved to the database.
# ✅ Completed 405/438
# ⏱️ 1s since last • 30m 40s total
# ----------------------------------------
#
# 🌍 Processing airport 406/438: VST
# ✅ Departure flights fetched successfully for VST.
# ✅ Arrival flights fetched successfully for VST.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 406/438
# ⏱️ 1s since last • 30m 42s total
# ----------------------------------------
#
# 🌍 Processing airport 407/438: UME
# ✅ Departure flights fetched successfully for UME.
# ✅ Arrival flights fetched successfully for UME.
# ✅ 4 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 407/438
# ⏱️ 2s since last • 30m 44s total
# ----------------------------------------
#
# 🌍 Processing airport 408/438: VXO
# ✅ Departure flights fetched successfully for VXO.
# ✅ Arrival flights fetched successfully for VXO.
# ✅ 1 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 408/438
# ⏱️ 1s since last • 30m 45s total
# ----------------------------------------
#
# 🌍 Processing airport 409/438: VBY
# ✅ Departure flights fetched successfully for VBY.
# ✅ Arrival flights fetched successfully for VBY.
# ✅ 4 new departure flights saved to the database.
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 409/438
# ⏱️ 1s since last • 30m 47s total
# ----------------------------------------
#
# 🌍 Processing airport 410/438: BHX
# ✅ Departure flights fetched successfully for BHX.
# ✅ Arrival flights fetched successfully for BHX.
# ✅ 106 new departure flights saved to the database.
# ✅ 60 new arrival flights saved to the database.
# ✅ Completed 410/438
# ⏱️ 10s since last • 30m 57s total
# ----------------------------------------
#
# 🌍 Processing airport 411/438: BOH
# ✅ Departure flights fetched successfully for BOH.
# ✅ Arrival flights fetched successfully for BOH.
# ✅ 11 new departure flights saved to the database.
# ✅ 6 new arrival flights saved to the database.
# ✅ Completed 411/438
# ⏱️ 1s since last • 30m 59s total
# ----------------------------------------
#
# 🌍 Processing airport 412/438: BRS
# ✅ Departure flights fetched successfully for BRS.
# ✅ Arrival flights fetched successfully for BRS.
# ✅ 42 new departure flights saved to the database.
# ✅ 22 new arrival flights saved to the database.
# ✅ Completed 412/438
# ⏱️ 5s since last • 31m 4s total
# ----------------------------------------
#
# 🌍 Processing airport 413/438: CWL
# ✅ Departure flights fetched successfully for CWL.
# ✅ Arrival flights fetched successfully for CWL.
# ✅ 12 new departure flights saved to the database.
# ✅ 13 new arrival flights saved to the database.
# ✅ Completed 413/438
# ⏱️ 3s since last • 31m 7s total
# ----------------------------------------
#
# 🌍 Processing airport 414/438: DSA
# ✅ Departure flights fetched successfully for DSA.
# ✅ Arrival flights fetched successfully for DSA.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new departure flights saved to the database.
# ⚠️ Skipping non-dict flight record: error
# ⚠️ Skipping non-dict flight record: success
# ✅ 0 new arrival flights saved to the database.
# ✅ Completed 414/438
# ⏱️ 0s since last • 31m 8s total
# ----------------------------------------
#
# 🌍 Processing airport 415/438: MME
# ✅ Departure flights fetched successfully for MME.
# ✅ Arrival flights fetched successfully for MME.
# ✅ 7 new departure flights saved to the database.
# ✅ 7 new arrival flights saved to the database.
# ✅ Completed 415/438
# ⏱️ 1s since last • 31m 10s total
# ----------------------------------------
#
# 🌍 Processing airport 416/438: EMA
# ✅ Departure flights fetched successfully for EMA.
# ✅ Arrival flights fetched successfully for EMA.
# ✅ 31 new departure flights saved to the database.
# ✅ 8 new arrival flights saved to the database.
# ✅ Completed 416/438
# ⏱️ 3s since last • 31m 14s total
# ----------------------------------------
#
# 🌍 Processing airport 417/438: EXT
# ✅ Departure flights fetched successfully for EXT.
# ✅ Arrival flights fetched successfully for EXT.
# ✅ 13 new departure flights saved to the database.
# ✅ 12 new arrival flights saved to the database.
# ✅ Completed 417/438
# ⏱️ 2s since last • 31m 16s total
# ----------------------------------------
#
# 🌍 Processing airport 418/438: LBA
# ✅ Departure flights fetched successfully for LBA.
# ✅ Arrival flights fetched successfully for LBA.
# ✅ 33 new departure flights saved to the database.
# ✅ 14 new arrival flights saved to the database.
# ✅ Completed 418/438
# ⏱️ 3s since last • 31m 20s total
# ----------------------------------------
#
# 🌍 Processing airport 419/438: LPL
# ✅ Departure flights fetched successfully for LPL.
# ✅ Arrival flights fetched successfully for LPL.
# ✅ 22 new departure flights saved to the database.
# ✅ 5 new arrival flights saved to the database.
# ✅ Completed 419/438
# ⏱️ 3s since last • 31m 23s total
# ----------------------------------------
#
# 🌍 Processing airport 420/438: LCY
# ✅ Departure flights fetched successfully for LCY.
# ✅ Arrival flights fetched successfully for LCY.
# ✅ 41 new departure flights saved to the database.
# ✅ 29 new arrival flights saved to the database.
# ✅ Completed 420/438
# ⏱️ 6s since last • 31m 29s total
# ----------------------------------------
#
# 🌍 Processing airport 421/438: LGW
# ✅ Departure flights fetched successfully for LGW.
# ✅ Arrival flights fetched successfully for LGW.
# ✅ 212 new departure flights saved to the database.
# ✅ 118 new arrival flights saved to the database.
# ✅ Completed 421/438
# ⏱️ 19s since last • 31m 49s total
# ----------------------------------------
#
# 🌍 Processing airport 422/438: LHR
# ✅ Departure flights fetched successfully for LHR.
# ✅ Arrival flights fetched successfully for LHR.
# ✅ 584 new departure flights saved to the database.
# ✅ 877 new arrival flights saved to the database.
# ✅ Completed 422/438
# ⏱️ 1m 3s since last • 32m 52s total
# ----------------------------------------
#
# 🌍 Processing airport 423/438: LTN
# ✅ Departure flights fetched successfully for LTN.
# ✅ Arrival flights fetched successfully for LTN.
# ✅ 60 new departure flights saved to the database.
# ✅ 36 new arrival flights saved to the database.
# ✅ Completed 423/438
# ⏱️ 7s since last • 32m 59s total
# ----------------------------------------
#
# 🌍 Processing airport 424/438: SEN
# ✅ Departure flights fetched successfully for SEN.
# ✅ Arrival flights fetched successfully for SEN.
# ✅ 3 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 424/438
# ⏱️ 1s since last • 33m 1s total
# ----------------------------------------
#
# 🌍 Processing airport 425/438: STN
# ✅ Departure flights fetched successfully for STN.
# ✅ Arrival flights fetched successfully for STN.
# ✅ 93 new departure flights saved to the database.
# ✅ 43 new arrival flights saved to the database.
# ✅ Completed 425/438
# ⏱️ 10s since last • 33m 11s total
# ----------------------------------------
#
# 🌍 Processing airport 426/438: MAN
# ✅ Departure flights fetched successfully for MAN.
# ✅ Arrival flights fetched successfully for MAN.
# ✅ 213 new departure flights saved to the database.
# ✅ 108 new arrival flights saved to the database.
# ✅ Completed 426/438
# ⏱️ 18s since last • 33m 29s total
# ----------------------------------------
#
# 🌍 Processing airport 427/438: NCL
# ✅ Departure flights fetched successfully for NCL.
# ✅ Arrival flights fetched successfully for NCL.
# ✅ 55 new departure flights saved to the database.
# ✅ 22 new arrival flights saved to the database.
# ✅ Completed 427/438
# ⏱️ 5s since last • 33m 35s total
# ----------------------------------------
#
# 🌍 Processing airport 428/438: NQY
# ✅ Departure flights fetched successfully for NQY.
# ✅ Arrival flights fetched successfully for NQY.
# ✅ 9 new departure flights saved to the database.
# ✅ 5 new arrival flights saved to the database.
# ✅ Completed 428/438
# ⏱️ 1s since last • 33m 37s total
# ----------------------------------------
#
# 🌍 Processing airport 429/438: NWI
# ⚠️ [NWI] Attempt 1/3 failed: HTTPError('404 Client Error: Not Found for url: https://aviation-edge.com/v2/public/timetable?key=abcf21-5fbf11&iataCode=NWI&type=departure')
#    ↳ retrying in 1s…
# ✅ Departure flights fetched successfully for NWI.
# ✅ Arrival flights fetched successfully for NWI.
# ✅ 13 new departure flights saved to the database.
# ✅ 15 new arrival flights saved to the database.
# ✅ Completed 429/438
# ⏱️ 5s since last • 33m 42s total
# ----------------------------------------
#
# 🌍 Processing airport 430/438: SOU
# ✅ Departure flights fetched successfully for SOU.
# ✅ Arrival flights fetched successfully for SOU.
# ✅ 27 new departure flights saved to the database.
# ✅ 24 new arrival flights saved to the database.
# ✅ Completed 430/438
# ⏱️ 3s since last • 33m 46s total
# ----------------------------------------
#
# 🌍 Processing airport 431/438: ABZ
# ✅ Departure flights fetched successfully for ABZ.
# ✅ Arrival flights fetched successfully for ABZ.
# ✅ 66 new departure flights saved to the database.
# ✅ 44 new arrival flights saved to the database.
# ✅ Completed 431/438
# ⏱️ 6s since last • 33m 52s total
# ----------------------------------------
#
# 🌍 Processing airport 432/438: EDI
# ✅ Departure flights fetched successfully for EDI.
# ✅ Arrival flights fetched successfully for EDI.
# ✅ 191 new departure flights saved to the database.
# ✅ 121 new arrival flights saved to the database.
# ✅ Completed 432/438
# ⏱️ 17s since last • 34m 9s total
# ----------------------------------------
#
# 🌍 Processing airport 433/438: GLA
# ✅ Departure flights fetched successfully for GLA.
# ✅ Arrival flights fetched successfully for GLA.
# ✅ 122 new departure flights saved to the database.
# ✅ 74 new arrival flights saved to the database.
# ✅ Completed 433/438
# ⏱️ 9s since last • 34m 18s total
# ----------------------------------------
#
# 🌍 Processing airport 434/438: PIK
# ✅ Departure flights fetched successfully for PIK.
# ✅ Arrival flights fetched successfully for PIK.
# ✅ 8 new departure flights saved to the database.
# ✅ 5 new arrival flights saved to the database.
# ✅ Completed 434/438
# ⏱️ 1s since last • 34m 20s total
# ----------------------------------------
#
# 🌍 Processing airport 435/438: INV
# ✅ Departure flights fetched successfully for INV.
# ✅ Arrival flights fetched successfully for INV.
# ✅ 26 new departure flights saved to the database.
# ✅ 17 new arrival flights saved to the database.
# ✅ Completed 435/438
# ⏱️ 2s since last • 34m 23s total
# ----------------------------------------
#
# 🌍 Processing airport 436/438: BFS
# ✅ Departure flights fetched successfully for BFS.
# ✅ Arrival flights fetched successfully for BFS.
# ✅ 13 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 436/438
# ⏱️ 3s since last • 34m 26s total
# ----------------------------------------
#
# 🌍 Processing airport 437/438: BHD
# ✅ Departure flights fetched successfully for BHD.
# ✅ Arrival flights fetched successfully for BHD.
# ✅ 29 new departure flights saved to the database.
# ✅ 20 new arrival flights saved to the database.
# ✅ Completed 437/438
# ⏱️ 4s since last • 34m 31s total
# ----------------------------------------
#
# 🌍 Processing airport 438/438: LDY
# ✅ Departure flights fetched successfully for LDY.
# ✅ Arrival flights fetched successfully for LDY.
# ✅ 5 new departure flights saved to the database.
# ✅ 2 new arrival flights saved to the database.
# ✅ Completed 438/438
# ⏱️ 1s since last • 34m 32s total
# ----------------------------------------
#
# 🎉 All 438 airports processed.
# 🕔 Completed at: 2025-06-09 13:02:47
# ⏱️ Total duration: 34m 32s
# 🔴 Ligação encerrada com sucesso!
